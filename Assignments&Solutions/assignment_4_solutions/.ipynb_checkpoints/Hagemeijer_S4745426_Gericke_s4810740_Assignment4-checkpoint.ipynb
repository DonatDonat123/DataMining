# %% [markdown]
# # Assignment 4
#
# ## Objective of this assignment
# The objective of this exercise is to understand how the unsupervised learning methods $k$-means clustering and hierarchical clustering work. Upon completing the exercise you should also understand how the choice of number of clusters, distance metrics and linkage functions can impact the solutions obtained and further be able to interpret dendrograms and measures of cluster validity
#
# ## ** Important: ** When handing in your homework:
# + Hand in the notebook (and nothing else) named as follows: StudentName1_snumber_StudentName2_snumber.ipynb
# + Provide clear and complete answers to the questions below under a separate header (not hidden somewhere in your source code), and make sure to explain your answers / motivate your choices. Add Markdown cells where necessary.
# + Source code, output graphs, derivations, etc., should be included in the notebook.
# + Hand-in: upload to Blackboard.
# + Include name, student number, assignment (especially in filenames)!
# + When working in pairs only one of you should upload the assignment, and report the name of your partner in your filename.
# + For problems or questions: use the BB discussion board or email the student assistants.
#
#
# ## Advised Reading and Exercise Material
# **The following reading material is recommended:**
#
# - Pang-Ning Tan, Michael Steinbach, and Vipin Kumar, *Introduction to Data Mining*, section 8.1-8.3 and 8.5.7
#
#
# ## Additional Tools
# For this exercise you will need to load the provided *clusterPlot.py* and *clusterVal.py* scripts.
#
#
# ## Introduction
# In previous exercises we considered supervised learning, i.e., we were given both input data **X** and output values **Y**. We now move on to unsupervised learning where we are only provided input data **X**. The aim is here to find common patterns in the data such as groups of observations that are similar in some sense. In this exercise we will consider two clustering approaches for unsupervised learning: *k*-means clustering and hierarchical clustering.
#
#
# ## 4.1 *k*-means clustering
# In this part of the exercise we will investigate *k*-means clustering. In *k*-means each of the data points are assigned to the cluster in closest proximity according to some measure of distance between cluster centers and data points. When the distance is given by the squared euclidian distance, the centers are also called centroids. Once the data points have been assigned, each cluster center is updated to be placed at the center of the data points that are assigned to the cluster. This continues iteratively, usually until the assignment of data points to centers no longer changes or until a maximal number of iterations is reached.
#
# > 4.1.1a (1 point) Load the *synth1* data into python using the *loadmat* function. Cluster the data into *K = 4* clusters using the *k*-means algorithm. Make a scatter plot of the data and the clustering using the provided *clusterPlot()* function.
#  + *In Python, you can use the function k_means() from the package sklearn.cluster to compute *k*-means clustering.*
#  + *Type clusterPlot(X,clusters,centroids,y) to plot the data and the clustering. Don't forget to import the function from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
##Answer to question 4.1.1a
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import k_means
from Toolbox.clusterPlot import clusterPlot
synthData = loadmat('Data/synth1.mat')
X = np.array(synthData['X'])
y = np.array(synthData['y'])
cenroids,label,innurs = k_means(X,4)
clusterPlot(X,label,cenroids,y)
plt.title('clutering synth 1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("the synth 1 data clustering with the k-means algoritm with k=4")
# Out:
# the synth 1 data clustering with the k-means algoritm with k=4

# %% [markdown]
# > 4.1.1b (1 point) Try also to cluster and plot the data sets *synth2*, *synth3*, and *synth4* with the same number of *K*. Does the clustering coincide with the true classes? Explain for every data set.

# %%
##Answer to question 4.1.1b
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import k_means
from Toolbox.clusterPlot import clusterPlot
synth2Data = loadmat('Data/synth2.mat')
X2 = np.array(synth2Data['X'])
y2 = np.array(synth2Data['y'])
cenroids2,label2,innurs2 = k_means(X2,4)
clusterPlot(X2,label2,cenroids2,y2)
plt.title('clutering synth 2')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("the synth 2 data clustering with the k-means algoritm with k=4")

synth3Data = loadmat('Data/synth3.mat')
X3 = np.array(synth3Data['X'])
y3 = np.array(synth3Data['y'])
cenroids3,label3,innurs3 = k_means(X3,4)
clusterPlot(X3,label3,cenroids3,y3)
plt.title('clutering synth 3')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("the synth 3 data clustering with the k-means algoritm with k=4")

synth4Data = loadmat('Data/synth4.mat')
X4 = np.array(synth4Data['X'])
y4 = np.array(synth4Data['y'])
cenroids4,label4,innurs4 = k_means(X4,4)
clusterPlot(X4,label4,cenroids4,y4)
plt.title('clutering synth 4')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("the synth 4 data clustering with the k-means algoritm with k=4")
# Out:
# the synth 2 data clustering with the k-means algoritm with k=4
# the synth 3 data clustering with the k-means algoritm with k=4
# the synth 4 data clustering with the k-means algoritm with k=4

# %% [markdown]
# *Double click to type your answer for 4.1.1b here:*
# The clusters don't look to work properly. For the first 2 the clusters aren not clustered to well. because with K-means taking the will never be able to properly "represent" a line. It will try to make blocks, not lines
# and the last data set is hard to cluster for k-means because the classes heavily overlap.

# %% [markdown]
# Rather than using the error rate we will consider the supervised measures of cluster validity described in *Introduction to Data Mining* section 8.5.7, in particular the entropy, purity, rand statistic, and Jaccard coefficient. Carefully review these measures in the book and make sure you understand how they are calculated.
#
# > 4.1.2a (1 point) Repeat Exercise 4.1.1, but this time perform *k*-means clustering for *K = 1, ..., 10* clusters. For each value of *K* compute the four cluster validity measures mentioned above. Plot the cluster validity measures as a function of *K*
#  + *Use the clusterVal() function to compute the cluster validity. Don't forget to import it from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
##Answer to question 4.1.2a

## legels x&y-as labes

import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import k_means
from Toolbox.clusterPlot import clusterPlot
from Toolbox.clusterVal import clusterVal

synthData = loadmat('Data/synth1.mat')
X = np.array(synthData['X'])
y = np.array(synthData['y'])
Entropylist = []
Puritylist = []
Randlist = []
jaccardlist= []
for k in range(1,11):
    cenroids,label,innurs = k_means(X,k)
    Entropy, Purity, Rand, Jaccard= clusterVal(y,label)
    Entropylist.append(Entropy)
    Puritylist.append(Purity)
    Randlist.append(Rand)
    jaccardlist.append(Jaccard)
x=range(1,11)
plt.plot(x,Entropylist,'red',x,Puritylist,'blue', x, Randlist, 'green', x, jaccardlist, 'yellow')
plt.ylabel('validity measure ')
plt.xlabel('number of cluster')
plt.title('validity measure on data synth 1')
plt.legend(loc='upper left')
plt.legend(["Entropy","purity", "Rand Statistics", "Jaccard" ],loc='upper right')
plt.show()
print("the 4 different validity measures of synth1 data after putting k-means data")

synth2Data = loadmat('Data/synth2.mat')
X2 = np.array(synth2Data['X'])
y2 = np.array(synth2Data['y'])
Entropylist2 = []
Puritylist2 = []
Randlist2 = []
jaccardlist2= []
for k in range(1,11):
    cenroids2,label2,innurs2 = k_means(X2,k)
    Entropy2, Purity2, Rand2, Jaccard2= clusterVal(y2,label2)
    Entropylist2.append(Entropy2)
    Puritylist2.append(Purity2)
    Randlist2.append(Rand2)
    jaccardlist2.append(Jaccard2)
    
plt.plot(x,Entropylist2,'red',x,Puritylist2,'blue', x, Randlist2, 'green', x, jaccardlist2, 'yellow')
plt.ylabel('validity measure ')
plt.xlabel('number of cluster')
plt.title('validity measure on data synth 2')
plt.legend(["Entropy","purity", "Rand Statistics", "Jaccard" ],loc='upper right')
plt.show()
print("the 4 different validity measures of synth2 data after putting k-means data")

synth3Data = loadmat('Data/synth3.mat')
X3 = np.array(synth2Data['X'])
y3 = np.array(synth2Data['y'])
Entropylist3 = []
Puritylist3 = []
Randlist3 = []
jaccardlist3= []
for k in range(1,11):
    cenroids3,label3,innurs3 = k_means(X3,k)
    Entropy3, Purity3, Rand3, Jaccard3= clusterVal(y3,label3)
    Entropylist3.append(Entropy3)
    Puritylist3.append(Purity3)
    Randlist3.append(Rand3)
    jaccardlist3.append(Jaccard3)
plt.plot(x,Entropylist3,'red',x,Puritylist3,'blue', x, Randlist3, 'green', x, jaccardlist3, 'yellow')
plt.ylabel('validity measure ')
plt.xlabel('number of cluster')
plt.title('validity measure on data synth 3')
plt.legend(["Entropy","purity", "Rand Statistics", "Jaccard" ],loc='upper right')
plt.show()
print("the 4 different validity measures of synth3 data after putting k-means data")

synth4Data = loadmat('Data/synth4.mat')
X4 = np.array(synth4Data['X'])
y4 = np.array(synth4Data['y'])
Entropylist4 = []
Puritylist4 = []
Randlist4 = []
jaccardlist4= []
for k in range(1,11):
    cenroids4,label4,innurs4 = k_means(X4,k)
    Entropy4, Purity4, Rand4, Jaccard4= clusterVal(y4,label4)
    Entropylist4.append(Entropy4)
    Puritylist4.append(Purity4)
    Randlist4.append(Rand4)
    jaccardlist4.append(Jaccard4)
plt.plot(x,Entropylist4,'red',x,Puritylist4,'blue', x, Randlist4, 'green', x, jaccardlist4, 'yellow')
plt.ylabel('validity measure ')
plt.xlabel('number of cluster')
plt.title('validity measure on data synth 4')
plt.legend(["Entropy","purity", "Rand Statistics", "Jaccard" ],loc='upper right')
plt.show()
print("the 4 different validity measures of synth4 data after putting k-means data")
# Out:
# C:\Users\Kayla Gericke\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# the 4 different validity measures of synth1 data after putting k-means data
# the 4 different validity measures of synth2 data after putting k-means data
# the 4 different validity measures of synth3 data after putting k-means data
# the 4 different validity measures of synth4 data after putting k-means data

# %% [markdown]
# > 4.1.2b (1 point) How can the cluster validity measures be used to select the best number of clusters?
# What happens when more than four clusters are used to model the data?

# %% [markdown]
# *Double click to type your answer for 4.1.2b here:*
# the entropy, purity, rand statistic, and Jaccard coefficient
#
# grootst: rand, jaccard,
#
# for the entropy you should pick the number of clusters where the entropy lowest or when adding more clusters does not make the entropy significantly lower.
# For the purity you should pick the number of clusters where the purity is high or when adding more clusters does not make the purity increase to much. This holds also for the Rand statistics and the Jaccard coefficient.
#
# adding more than four clusters does not improve the clustering a lot.

# %% [markdown]
# *k*-means clustering has many different applications, one of which is data compression. A data set can be compressed by performing *k*-means clustering and then representing each data object by its cluster center. Thus, the only data that need to be stored are the *K* cluster centers and the *N* cluster indices.
#
# > 4.1.3a (1 point) We will consider a subset of the wild faces data described in berg2005[1]. Load the wildfaces data, *Data/wildfaces* using the *loadmat* function. Each data object is a $40 \times 40 \times 3 = 4800$ dimensional vector, corresponding to a 3-color $40 \times 40$ pixels image. Compute a *k*-means clustering of the data with *K = 10* clusters. Plot a few random images from the data set as well as their corresponding cluster centroids to see how they are represented.
# + You can plot an image by the command imshow(np.reshape(X[k,:],(c,x,y)).T) which reshapes an image vector to a 3-dimensional array and plots it. You can plot the cluster centroids in a similar manner.
# + Running *k*-means on a large data set can be slow. If you type k_means(X, K, verbose=True, max_iter=X, n_init=S) it will provide information about the iterations as they run. As before, n_init  constrains the number of initial repeated centroid seeds. Type help(kmeans) (or read the documentation) to read more about these options.

# %%
##Answer to question 4.1.3a
# %matplotlib inline
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn import metrics
from sklearn.cluster import k_means
from Toolbox.clusterPlot import clusterPlot
wildD= loadmat('Data/wildfaces.mat')
x = np.array(wildD['X'])

k=10
centroids,label,innurs = k_means(x,k)

plt.imshow(np.reshape(x[0,:],(3,40,40)).T) 
plt.title('picture 0 made with original data')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

plt.imshow(np.reshape(centroids[label[0],:],(3,40,40)).T) 
plt.title('picture 0 made with centroids after applying k-means')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


plt.imshow(np.reshape(x[10,:],(3,40,40)).T) 
plt.title('picture 10 made with original data')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

plt.imshow(np.reshape(centroids[label[10],:],(3,40,40)).T) 
plt.title('picture 10 made with centroids after applying k-means')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


plt.imshow(np.reshape(x[101,:],(3,40,40)).T) 
plt.title('picture 101 made with original data')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

plt.imshow(np.reshape(centroids[label[101],:],(3,40,40)).T) 
plt.title('picture 101 made with centroids after applying k-means')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# > 4.1.3b (1 point) How well is the data represented by the cluster centroids? Are you able to recognize the faces in the compressed representation? What happens if you increase or decrease the number of clusters?

# %% [markdown]
# *Double click to type your answer for 4.1.3b here:*
# It is at least recognizable a face, but it looks pretty blurry.
# when we increase or descrease the amound of k it does not seem to have to much effect. More clusters seem to be a bit better, but adding 200 or more clusters don't make it much better. (but our computers get much slower)

# %% [markdown]
# > 4.1.4a (1 point) Repeat the exercise with the digits data set. Load the digits data set from Data/digits. Each data object is a $16 \times 16 = 256$ dimensional vector, corresponding to a gray scale $16 \times 16$ pixels image.
# + You can change the color map to black-on-white gray-scale by adding the parameter cmap=cm.binary to the function imshow().

# %%
##Answer to question 4.1.4a
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from sklearn.cluster import k_means
digD= loadmat('Data/digits.mat')
x = np.array(digD['X'])
y = np.array(digD['y'])

k=50
centroids,label,innurs = k_means(x,k)

for i in range(0,10):
    plt.subplot(5,2,(i+1)); #(rij, colom, hoeveelste)
    plt.imshow(np.reshape(x[i,:],(16,16)), cmap=plt.cm.binary);
    plt.suptitle('Digit as an image');
    plt.xlabel('x')
    plt.ylabel('y')
plt.show()
print("first 10 different didgets form a data set")

for i in range(0,10):
    plt.subplot(5,2,(i+1)); #(rij, colom, hoeveelste)
    plt.imshow(np.reshape(centroids[label[i],:],(16,16)), cmap=plt.cm.binary);
    plt.suptitle('Digit as an image');
    plt.xlabel('x')
    plt.ylabel('y')
plt.show()
print("The 10 corresponding didgets after applaying k-means algoritm with k=10")
# Out:
# first 10 different didgets form a data set
# The 10 corresponding didgets after applaying k-means algoritm with k=10

# %% [markdown]
# > 4.1.4b (1 point) Why does running *k*-means with *K = 10* not give you 10 clusters corresponding to the 10 digits *0..9*? How many clusters do you need to visually represent the 10 different digits? Are there any digits that the clustering algorithm seems to confuse more than others and can you explain why?

# %%
##Answer to question 4.1.4b

# %% [markdown]
# *Double click to type your answer for 4.1.4b here:*
# Because k-means takes random starting points, so for example it could be that it splits one of the digits into 2 clusters. there fore we would need more clusters. 100 clusters for example works pretty well actually.
# with 10 clusters it has toubles with 7 & 9s and a 4 also seems difficuilt for it.

# %% [markdown]
# ## 4.2 Hierarchical Clustering
#
# In this part of the exercise we will consider hierarchical clustering based on the functions from the package *scipy.cluster.hierarchy*. The function *linkage()* forms a sample to sample distance matrix according to a given distance metric, and creates the linkages between data points forming the hierarchical cluster tree. The function *dendrogram* creates a plot of the generated tree. The function *fcluster* extracts the cluster from a linkage matrix w.r.t. a given criterion. Use *help* for the three functions (or read the online documentation) and inspect what distance metrics and linkage functions are implemented.
#
# > 4.2.1a (1 point) Load the data set from *Data/synth1*. Cluster the data using hierarchical clustering with single linkage using the Euclidean distance measure. Cluster the data into 4 clusters by cutting off the dendrogram at a threshold. Plot a dendrogram and a scatter plot of the clusters.
# + The function *linkage()* computes the hierarchical clustering, resulting in a matrix representing the hierarchy of clusterings. Type help(linkage) (or read the online documentation) to learn how to use it.
# + You can e.g. type *Z = linkage(X, method='single', metric='euclidean')* to use single linkage with the Euclidean distance measure.
# + To compute a clustering, you can use the function*fcluster()*. For example, type *cls = fcluster(Z, criterion='maxclust', t=4)* to get a maximum of 4 clusters. Type *help(fcluster)* (or read the online documentation) to learn more about what this function does.
# + To plot a dendrogram, you can use the *dendrogram()* function
# + Again, you can use the function *clusterplot()* to plot a scatter plot of the clustering.

# %%
##Answer to question 4.2.1a
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from sklearn.cluster import k_means
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from Toolbox.clusterPlot import clusterPlot

synth1= loadmat('Data/synth1.mat')
X = np.array(synth1['X'])
y = np.array(synth1['y'])
Z = linkage(X, method='single', metric= 'euclidean')
cls= fcluster(Z, criterion='maxclust', t=4)
dendrogram(Z, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth1')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the single method to create the distancematrix on the synth 1 data")

clusterPlot(X,cls, y= y)
plt.title('clusters of synth 1 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the single method to create the distancematrix on the synth 1 data")
# dendrogram(Z, color_threshold=0.5, p=5,truncate_mode = 'lastp')
# plt.show()
# Out:
# The dendrogram created when using the single method to create the distancematrix on the synth 1 data
# Toolbox\clusterPlot.py:45: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True)
# C:\Users\Kayla Gericke\Anaconda2\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\Kayla Gericke\Anaconda2\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# Toolbox\clusterPlot.py:62: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
# ...

# %% [markdown]
# > 4.2.1b (1 point) Change the linkage methods (single, complete, average) and explain how this changes the dendrogram.
# Then plot a dendrogram and a scatterplot of the clusters for the *synth2*, *synth3*, and *synth4* data sets..

# %%
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
from sklearn.cluster import k_means
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from Toolbox.clusterPlot import clusterPlot

print("synth data 1")
synth1= loadmat('Data/synth1.mat')
X = np.array(synth1['X'])
y = np.array(synth1['y'])

Z = linkage(X, method='complete', metric= 'euclidean')
cls= fcluster(Z, criterion='maxclust', t=4)
dendrogram(Z, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth1 using max distance mesurement')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the complete method to create the distancematrix on the synth 1 data")

clusterPlot(X,cls, y= y)
plt.title('clusters of synth 1 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the complete method to create the distancematrix on the synth 1 data")


Z = linkage(X, method='average', metric= 'euclidean')
cls= fcluster(Z, criterion='maxclust', t=4)
dendrogram(Z, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth1 using average distance mesurement')
plt.xlabel('data points')
plt.ylabel('max distance')
plt.show()
print("The dendrogram created when using the avarage method to create the distancematrix on the synth 1 data")

clusterPlot(X,cls, y= y)
plt.title('clusters of synth 1 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the avarage method to create the distancematrix on the synth 1 data")

print("synth data 2")
synth2= loadmat('Data/synth2.mat')
X2 = np.array(synth2['X'])
y2 = np.array(synth2['y'])
Z2 = linkage(X2, method='single', metric= 'euclidean')
cls2= fcluster(Z2, criterion='maxclust', t=4)
dendrogram(Z2, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth2')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the single method to create the distancematrix on the synth 2 data")

clusterPlot(X2,cls2, y= y2)
plt.title('clusters of synth 2 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the single method to create the distancematrix on the synth 2 data")
      
Z2 = linkage(X2, method='complete', metric= 'euclidean')
cls2= fcluster(Z2, criterion='maxclust', t=4)
dendrogram(Z2, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth2 using max distance mesurement')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the complete method to create the distancematrix on the synth 2 data")

clusterPlot(X2,cls2, y=y2)
plt.title('clusters of synth 2 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the complete method to create the distancematrix on the synth 2 data")

Z2 = linkage(X2, method='average', metric= 'euclidean')
cls2= fcluster(Z2, criterion='maxclust', t=4)
dendrogram(Z2, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth2 using average distance mesurement')
plt.xlabel('data points')
plt.ylabel('max distance')
plt.show()
print("The dendrogram created when using the avarage method to create the distancematrix on the synth 2 data")

clusterPlot(X2,cls2, y= y2)
plt.title('clusters of synth 2 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the avarage method to create the distancematrix on the synth 2 data")

print("synth 3")
synth3= loadmat('Data/synth3.mat')
X3 = np.array(synth3['X'])
y3 = np.array(synth3['y'])
Z3 = linkage(X3, method='single', metric= 'euclidean')
cls3= fcluster(Z3, criterion='maxclust', t=4)
dendrogram(Z3, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth3')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the single method to create the distancematrix on the synth 3 data")

      
clusterPlot(X3,cls3, y= y3)
plt.title('clusters of synth 3 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the single method to create the distancematrix on the synth 3 data")

Z3 = linkage(X3, method='complete', metric= 'euclidean')
cls3= fcluster(Z3, criterion='maxclust', t=4)
dendrogram(Z3, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth3 using max distance mesurement')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the complete method to create the distancematrix on the synth 3 data")

clusterPlot(X3,cls3, y=y3)
plt.title('clusters of synth 3 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the complete method to create the distancematrix on the synth 3 data")

Z3 = linkage(X3, method='average', metric= 'euclidean')
cls3= fcluster(Z3, criterion='maxclust', t=4)
dendrogram(Z3, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth3 using average distance mesurement')
plt.xlabel('data points')
plt.ylabel('max distance')
plt.show()
print("The dendrogram created when using the avarage method to create the distancematrix on the synth 3 data")


clusterPlot(X3,cls3, y= y3)
plt.title('clusters of synth 3 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the avarage method to create the distancematrix on the synth 3 data")

print("synth data 4")
synth4= loadmat('Data/synth4.mat')
X4 = np.array(synth4['X'])
y4 = np.array(synth4['y'])
Z4 = linkage(X4, method='single', metric= 'euclidean')
cls4= fcluster(Z4, criterion='maxclust', t=4)
dendrogram(Z4, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth4')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the single method to create the distancematrix on the synth 4 data")

clusterPlot(X4,cls4, y= y4)
plt.title('clusters of synth 4 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the single method to create the distancematrix on the synth 4 data")

Z4 = linkage(X4, method='complete', metric= 'euclidean')
cls4= fcluster(Z4, criterion='maxclust', t=4)
dendrogram(Z4, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth4 using max distance mesurement')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
print("The dendrogram created when using the complete method to create the distancematrix on the synth 4 data")
      
clusterPlot(X4,cls4, y=y4)
plt.title('clusters of synth 4 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the complete method to create the distancematrix on the synth 4 data")


Z4= linkage(X4, method='average', metric= 'euclidean')
cls4= fcluster(Z4, criterion='maxclust', t=4)
dendrogram(Z4, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth4 using average distance mesurement')
plt.xlabel('data points')
plt.ylabel('max distance')
plt.show()
print("The dendrogram created when using the avarage method to create the distancematrix on the synth 4 data")
      
clusterPlot(X4,cls4, y= y4)
plt.title('clusters of synth 4 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print("The clusters formed when using the avarage method to create the distancematrix on the synth 4 data")
# Out:
# synth data 1
# The dendrogram created when using the complete method to create the distancematrix on the synth 1 data
# The clusters formed when using the complete method to create the distancematrix on the synth 1 data
# The dendrogram created when using the avarage method to create the distancematrix on the synth 1 data
# The clusters formed when using the avarage method to create the distancematrix on the synth 1 data
# synth data 2
# The dendrogram created when using the single method to create the distancematrix on the synth 2 data
# The clusters formed when using the single method to create the distancematrix on the synth 2 data
# The dendrogram created when using the complete method to create the distancematrix on the synth 2 data
# The clusters formed when using the complete method to create the distancematrix on the synth 2 data
# The dendrogram created when using the avarage method to create the distancematrix on the synth 2 data
# ...

# %% [markdown]
# *Double click to type your answer for 4.1.3b here:*
# it doesn't really matter which distance method you use when making the clustering. it is all more or les the same. (not to good for synth data 2,3 and 4.
#
#
#
# !!!! kayla, ik denk dat dit weg kan. en dat dat genoeg moet zijn !!!!
# synth data 1:
# complete(max):
# average:
#
# synth data 2:
# single(min):
# complete(max):
# average:
#
# synth data 3:
# single(min):
# complete(max):
# average:
#
# synth data 4:
# single(min):
# complete(max):
# average:

# %% [markdown]
# ## References
# 1. Tamara L Berg, Alexander C Berg, Jaety Edwards, and DA Forsyth. Who's in the
# picture. *Advances in Neural Information Processing Systems*, 17:137-144, 2005.

# %%
## aantekening voor mezelf als ik ga leren. Lieve TA negeer dit. 

print("synth data 2")
synth2= loadmat('Data/synth2.mat')
X2 = np.array(synth2['X'])
y2 = np.array(synth2['y'])
Z2 = linkage(X2, method='single', metric= 'cosine')
cls2= fcluster(Z2, criterion='maxclust', t=4)
dendrogram(Z2, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth2')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()

clusterPlot(X2,cls2, y= y2)
plt.title('clusters of synth 2 given cls with fcluster')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

Z2 = linkage(X2, method='complete', metric= 'euclidean')
cls2= fcluster(Z2, criterion='maxclust', t=4)
dendrogram(Z2, color_threshold=0.5)
plt.title('dendrogram of the hierarchical clustering of synth2 using max distance mesurement')
plt.xlabel('data points')
plt.ylabel('euclidean distance')
plt.show()
# Out:
# synth data 2
