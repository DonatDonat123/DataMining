# %% [markdown]
# # Assignment 4
#
# ## Objective of this assignment
# The objective of this exercise is to understand how the unsupervised learning methods $k$-means clustering and hierarchical clustering work. Upon completing the exercise you should also understand how the choice of number of clusters, distance metrics and linkage functions can impact the solutions obtained and further be able to interpret dendrograms and measures of cluster validity
#
# ## ** Important: ** When handing in your homework:
# + Hand in the notebook (and nothing else) named as follows: StudentName1_snumber_StudentName2_snumber.ipynb
# + Provide clear and complete answers to the questions below under a separate header (not hidden somewhere in your source code), and make sure to explain your answers / motivate your choices. Add Markdown cells where necessary.
# + Source code, output graphs, derivations, etc., should be included in the notebook.
# + Hand-in: upload to Blackboard.
# + Include name, student number, assignment (especially in filenames)!
# + When working in pairs only one of you should upload the assignment, and report the name of your partner in your filename.
# + For problems or questions: use the BB discussion board or email the student assistants.
#
#
# ## Advised Reading and Exercise Material
# **The following reading material is recommended:**
#
# - Pang-Ning Tan, Michael Steinbach, and Vipin Kumar, *Introduction to Data Mining*, section 8.1-8.3 and 8.5.7
#
#
# ## Additional Tools
# For this exercise you will need to load the provided *clusterPlot.py* and *clusterVal.py* scripts.
#
#
# ## Introduction
# In previous exercises we considered supervised learning, i.e., we were given both input data **X** and output values **Y**. We now move on to unsupervised learning where we are only provided input data **X**. The aim is here to find common patterns in the data such as groups of observations that are similar in some sense. In this exercise we will consider two clustering approaches for unsupervised learning: *k*-means clustering and hierarchical clustering.
#
#
# ## 4.1 *k*-means clustering
# In this part of the exercise we will investigate *k*-means clustering. In *k*-means each of the data points are assigned to the cluster in closest proximity according to some measure of distance between cluster centers and data points. When the distance is given by the squared euclidian distance, the centers are also called centroids. Once the data points have been assigned, each cluster center is updated to be placed at the center of the data points that are assigned to the cluster. This continues iteratively, usually until the assignment of data points to centers no longer changes or until a maximal number of iterations is reached.
#
# > 4.1.1a (1 point) Load the *synth1* data into python using the *loadmat* function. Cluster the data into *K = 4* clusters using the *k*-means algorithm. Make a scatter plot of the data and the clustering using the provided *clusterPlot()* function.
#  + *In Python, you can use the function k_means() from the package sklearn.cluster to compute *k*-means clustering.*
#  + *Type clusterPlot(X,clusters,centroids,y) to plot the data and the clustering. Don't forget to import the function from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
## Ralph van Eerdt: S4800702
## Paul Heldens: s4753127
##Answer to question 4.1.1a
from scipy.io import loadmat
import numpy as np
import sklearn.cluster as skc
import clusterPlot
import matplotlib.pyplot as plt
synth1 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth1.mat")
X1 = synth1["X"]
Y1 = synth1["y"].ravel()
kmeans = skc.k_means(X1, n_clusters = 4)
clusters = kmeans[1]
centroids = kmeans[0]
clusterPlot.clusterPlot(X1, clusters, centroids, Y1)
plt.title("Clusterplot synth1")
plt.xlabel("first component")
plt.ylabel("second component")
plt.show()

# %% [markdown]
# > 4.1.1b (1 point) Try also to cluster and plot the data sets *synth2*, *synth3*, and *synth4* with the same number of *K*. Does the clustering coincide with the true classes? Explain for every data set.

# %%
##Answer to question 4.1.1b
synth2 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth2.mat")
X2 = synth2["X"]
Y2 = synth2["y"].ravel()
kmeans2 = skc.k_means(X2, n_clusters = 4)
clusters2 = kmeans2[1]
centroids2 = kmeans2[0]
clusterPlot.clusterPlot(X2, clusters2, centroids2, Y2)
plt.title("Clusterplot synth2")
plt.xlabel("first component")
plt.ylabel("second component")
plt.show()

synth3 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth3.mat")
X3 = synth3["X"]
Y3 = synth3['y'].ravel()
kmeans3 = skc.k_means(X3, n_clusters = 4)
clusters3 = kmeans3[1]
centroids3 = kmeans3[0]
clusterPlot.clusterPlot(X3, clusters3, centroids3, Y3)
plt.title("Clusterplot synth3")
plt.xlabel("first component")
plt.ylabel("second component")
plt.show()

synth4 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth4.mat")
X4 = synth4["X"]
Y4 = synth4['y'].ravel()
kmeans4 = skc.k_means(X4, n_clusters = 4)
clusters4 = kmeans4[1]
centroids4 = kmeans4[0]
clusterPlot.clusterPlot(X4, clusters4, centroids4, Y4)
plt.title("Clusterplot synth4")
plt.xlabel("first component")
plt.ylabel("second component")
plt.show()

# %% [markdown]
# In the first data set (synth1.mat) it seems that the clustering coincide with the classes correctly. The colors don't always match but because the colouring changes every time the assignment is run. So we assume that the colours do not matter if all the points from one class are in the same cluster.
#
# In the second data set (synth2.mat) the classes are the four lines which do not coincide with the clusters. The classes run horizontal and the clusters and centroids vertical which means that the classes are clustered in all four different clusters, so not properly coincide.
#
# In the third data set (synth3.mat) is the mostly the same as the the second data set but now the classes and centroids are vertical and the clusters horizontal distributed. This means that the classes are clustered in all four the clusters, which is definately not properly coincide.
#
# In the last data set (synth4.mat) the classes are overlapping, which means that it is hard to see if the clusters properly  coincide with the classes. But the clustering is propably not correct.
# In conclusion it seems that this algorithm only works on the simple datasets without any complex data.

# %% [markdown]
# Rather than using the error rate we will consider the supervised measures of cluster validity described in *Introduction to Data Mining* section 8.5.7, in particular the entropy, purity, rand statistic, and Jaccard coefficient. Carefully review these measures in the book and make sure you understand how they are calculated.
#
# > 4.1.2a (1 point) Repeat Exercise 4.1.1, but this time perform *k*-means clustering for *K = 1, ..., 10* clusters. For each value of *K* compute the four cluster validity measures mentioned above. Plot the cluster validity measures as a function of *K*
#  + *Use the clusterVal() function to compute the cluster validity. Don't forget to import it from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
##Answer to question 4.1.2a
import clusterVal
import matplotlib.pyplot as plt
synth1 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth1.mat")
X = synth1["X"]
Y = synth1["y"].ravel()
entropy = []
purity = []
rand = []
jaccard = []
for K in range(1,11):
    k_means = skc.k_means(X, K)
    entropy.append(clusterVal.clusterVal(Y, k_means[1])[0])
    purity.append(clusterVal.clusterVal(Y, k_means[1])[1])
    rand.append(clusterVal.clusterVal(Y, k_means[1])[2])
    jaccard.append(clusterVal.clusterVal(Y, k_means[1])[3])
plt.plot(range(1,11), entropy, range(1,11), purity, range(1,11), rand, range(1,11), jaccard )
plt.title("Cluster validity measures vs K")
plt.xlabel("K")
plt.ylabel("Cluster valididty measures")
plt.legend(['Entropy', 'Purity', 'Rand', 'Jaccard'])
plt.show()

# %% [markdown]
# > 4.1.2b (1 point) How can the cluster validity measures be used to select the best number of clusters?
# What happens when more than four clusters are used to model the data?

# %% [markdown]
# When most of the cluster valididity have reached their favoured position you can probably state that that is the position with the best number of clusters. After the k=4 the number of clusters does not influence the cluster valididity much. So that is the best number of clusters.

# %% [markdown]
# *k*-means clustering has many different applications, one of which is data compression. A data set can be compressed by performing *k*-means clustering and then representing each data object by its cluster center. Thus, the only data that need to be stored are the *K* cluster centers and the *N* cluster indices.
#
# > 4.1.3a (1 point) We will consider a subset of the wild faces data described in berg2005[1]. Load the wildfaces data, *Data/wildfaces* using the *loadmat* function. Each data object is a $40 \times 40 \times 3 = 4800$ dimensional vector, corresponding to a 3-color $40 \times 40$ pixels image. Compute a *k*-means clustering of the data with *K = 10* clusters. Plot a few random images from the data set as well as their corresponding cluster centroids to see how they are represented.
# + You can plot an image by the command imshow(np.reshape(X[k,:],(c,x,y)).T) which reshapes an image vector to a 3-dimensional array and plots it. You can plot the cluster centroids in a similar manner.
# + Running *k*-means on a large data set can be slow. If you type k_means(X, K, verbose=True, max_iter=X, n_init=S) it will provide information about the iterations as they run. As before, n_init  constrains the number of initial repeated centroid seeds. Type help(kmeans) (or read the documentation) to read more about these options.

# %%
##Answer to question 4.1.3a
from scipy.io import loadmat
import numpy as np
import sklearn.cluster as skc
wildfaces = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\wildfaces.mat")
X = wildfaces["X"]
skc.k_means(X, 10, verbose=True, max_iter=len(X), n_init=1)
plt.imshow(np.reshape(X[99,:],(3,40,40)).T)
plt.show()
plt.imshow(np.reshape(X[22,:],(3,40,40)).T)
plt.show()
plt.imshow(np.reshape(X[14,:],(3,40,40)).T)
plt.show()
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 174888.152998
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 165319.981488
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 162865.452895
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 161229.943377
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 160078.478262
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 159268.337394
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 158512.212802
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 157929.979271
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 157622.911915
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 157453.547746
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 157345.621221
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 157321.683294
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 157315.53932
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 157315.53932
# center shift 0.000000e+00 within tolerance 4.494303e-06

# %% [markdown]
# > 4.1.3b (1 point) How well is the data represented by the cluster centroids? Are you able to recognize the faces in the compressed representation? What happens if you increase or decrease the number of clusters?

# %%
##Answer to question 4.1.3b
kmeans = skc.k_means(X, n_clusters = 500)
centroids = kmeans[0]
clusters = kmeans [1]
skc.k_means(X, 10, verbose=True, max_iter=len(X), n_init=1)
plt.imshow(np.reshape(centroids[clusters[99],:],(3,40,40)).T)
plt.show()
plt.imshow(np.reshape(centroids[clusters[22],:],(3,40,40)).T)
plt.show()
plt.imshow(np.reshape(centroids[clusters[14],:],(3,40,40)).T)
plt.show()
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 169157.167541
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 162990.971683
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 160593.682466
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 159411.637926
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 158981.113772
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 158800.893566
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 158651.082974
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 158453.214102
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 158227.340973
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 158018.004647
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 157935.185012
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 157888.341147
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 157825.861801
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 157774.87503
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 157756.034503
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 157739.630017
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 157724.85915
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 157720.424922
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 157720.424922
# center shift 0.000000e+00 within tolerance 4.494303e-06

# %% [markdown]
# When you increase the number of clusters the pictures become more readable and the loading time increases, so it seems that if there are more clusters there are more pixels and more processing. The faces are recognizable but slightly pixelated.

# %% [markdown]
# > 4.1.4a (1 point) Repeat the exercise with the digits data set. Load the digits data set from Data/digits. Each data object is a $16 \times 16 = 256$ dimensional vector, corresponding to a gray scale $16 \times 16$ pixels image.
# + You can change the color map to black-on-white gray-scale by adding the parameter cmap=cm.binary to the function imshow().

# %%
##Answer to question 4.1.4a
from scipy.io import loadmat
import numpy as np
import sklearn.cluster as skc
import matplotlib.pyplot as plt
digits = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\digits.mat")
X = digits["X"]
skc.k_means(X, 10, verbose=True, max_iter=len(X), n_init=1)
plt.imshow(np.reshape(X[10,:],(16,16)).T, cmap=plt.cm.binary)
plt.show()
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 814715.926595
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 750760.221232
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 735906.783918
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 733154.555351
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 731483.417215
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 730126.433246
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 728587.158495
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 726494.022466
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 724874.227441
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 723879.527107
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 723150.418176
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 722601.698247
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 722160.730502
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 721784.4832
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 721416.942113
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 720972.340273
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 720444.002841
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 719854.835416
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 719332.476325
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 718977.048646
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 718703.107904
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 718591.213766
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 718545.167742
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 718529.988067
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 718519.39007
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 718516.16074
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 718515.374922
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 718514.3973
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 718513.923811
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 718513.49117
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 718512.609612
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 718512.28053
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 718512.134447
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 718512.010758
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 718511.328143
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 718511.192029
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 718510.999705
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 718510.862619
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 718510.696892
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 718510.336083
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 718509.829991
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 718509.545637
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 718509.401968
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 718509.23038
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 718509.071421
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 718509.071421
# center shift 0.000000e+00 within tolerance 4.763072e-05

# %% [markdown]
# > 4.1.4b (1 point) Why does running *k*-means with *K = 10* not give you 10 clusters corresponding to the 10 digits *0..9*? How many clusters do you need to visually represent the 10 different digits? Are there any digits that the clustering algorithm seems to confuse more than others and can you explain why?

# %%
##Answer to question 4.1.4b

# %% [markdown]
# *Double click to type your answer for 4.1.3b here:*

# %% [markdown]
# ## 4.2 Hierarchical Clustering
#
# In this part of the exercie we will consider hierarchical clustering based on the functions from the package *scipy.cluster.hierarchy*. The function *linkage()* forms a sample to sample distance matrix according to a given distance metric, and creates the linkages between data points forming the hierarchical cluster tree. The function *dendrogram* creates a plot of the generated tree. The function *fcluster* extracts the cluster from a linkage matrix w.r.t. a given criterion. Use *help* for the three functions (or read the online documentation) and inspect what distance metrics and linkage functions are implemented.
#
# > 4.2.1a (1 point) Load the data set from *Data/synth1*. Cluster the data using hierarchical clustering with single linkage using the Euclidean distance measure. Cluster the data into 4 clusters by cutting off the dendrogram at a threshold. Plot a dendrogram and a scatter plot of the clusters.
# + The function *linkage()* computes the hierarchical clustering, resulting in a matrix representing the hierarchy of clusterings. Type help(linkage) (or read the online documentation) to learn how to use it.
# + You can e.g. type *Z = linkage(X, method='single', metric='euclidean')* to use single linkage with the Euclidean distance measure.
# + To compute a clustering, you can use the function*fcluster()*. For example, type *cls = fcluster(Z, criterion='maxclust', t=4)* to get a maximum of 4 clusters. Type *help(fcluster)* (or read the online documentation) to learn more about what this function does.
# + To plot a dendrogram, you can use the *dendrogram()* function
# + Again, you can use the function *clusterplot()* to plot a scatter plot of the clustering.

# %%
##Answer to question 4.2.1a
from scipy.io import loadmat
import numpy as np
import sklearn.cluster as skc
from scipy.cluster import hierarchy as hac
import matplotlib.pyplot as plt
import clusterPlot as cl
synth1 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth1.mat")
X1 = synth1["X"]
Y1 = synth1["y"].ravel()
kmeans = skc.k_means(X1, n_clusters = 4)
clusters = kmeans[1]
centroids = kmeans[0]
Z = hac.linkage(X1, method='single', metric = 'euclidean')
cls = hac.fcluster(Z, criterion = 'maxclust', t=4)
plt.figure()
plt.title("Dendrogram single plot synth1")
plt.xlabel("Observations")
plt.ylabel("Distance")
hac.dendrogram(Z)
plt.show()
plt.title("clusterplot synth1")
plt.xlabel("first component")
plt.ylabel("second component")
cl.clusterPlot(X1, clusters, centroids, Y1) 
plt.show()

# %% [markdown]
# > 4.2.1b (1 point) Change the linkage methods (single, complete, average) and explain how this changes the dendrogram.
# Then plot a dendrogram and a scatterplot of the clusters for the *synth2*, *synth3*, and *synth4* data sets..

# %%
##Answer to question 4.2.1b
##complete plot synth 1
Z = hac.linkage(X1, method='complete', metric = 'euclidean')
cls = hac.fcluster(Z, criterion = 'maxclust', t=4)
plt.figure()
plt.title("Dendrogram complete plot synth1")
plt.xlabel("Observations")
plt.ylabel("Distance")
hac.dendrogram(Z)
plt.show()
##average plot synth 1
Z = hac.linkage(X1, method='average', metric = 'euclidean')
cls = hac.fcluster(Z, criterion = 'maxclust', t=4)
plt.figure()
plt.title("Dendrogram average plot synth1")
plt.xlabel("Observations")
plt.ylabel("Distance")
hac.dendrogram(Z)
plt.show()
## synth 2
synth2 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth2.mat")
X2 = synth2["X"]
Y2 = synth2["y"].ravel()
kmeans = skc.k_means(X2, n_clusters = 4)
clusters = kmeans[1]
centroids = kmeans[0]
Z = hac.linkage(X2, method='single', metric = 'euclidean')
cls = hac.fcluster(Z, criterion = 'maxclust', t=4)
plt.figure()
plt.title("Dendrogram single plot synth2")
plt.xlabel("Observations")
plt.ylabel("Distance")
hac.dendrogram(Z)
plt.show()
plt.title("clusterplot synth2")
plt.xlabel("first component")
plt.ylabel("second component")
cl.clusterPlot(X2, clusters, centroids, Y2) 
plt.show()
## synth3
synth3 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth3.mat")
X3 = synth3["X"]
Y3 = synth3["y"].ravel()
kmeans = skc.k_means(X3, n_clusters = 4)
clusters = kmeans[1]
centroids = kmeans[0]
Z = hac.linkage(X3, method='complete', metric = 'euclidean')
cls = hac.fcluster(Z, criterion = 'maxclust', t=4)
plt.figure()
plt.title("Dendrogram complete plot synth3")
plt.xlabel("Observations")
plt.ylabel("Distance")
hac.dendrogram(Z)
plt.show()
plt.title("clusterplot synth3")
plt.xlabel("first component")
plt.ylabel("second component")
cl.clusterPlot(X3, clusters, centroids, Y3) 
plt.show()
## synth 4
synth4 = loadmat("C:\Users\Gebruiker\Documents\AI\Data Mining\Assignment_4\Data\synth4.mat")
X4 = synth4["X"]
Y4 = synth4["y"].ravel()
kmeans = skc.k_means(X4, n_clusters = 4)
clusters = kmeans[1]
centroids = kmeans[0]
Z = hac.linkage(X4, method='average', metric = 'euclidean')
cls = hac.fcluster(Z, criterion = 'maxclust', t=4)
plt.figure()
plt.title("Dendrogram average plot synth4")
plt.xlabel("Observations")
plt.ylabel("Distance")
hac.dendrogram(Z)
plt.show()
plt.title("clusterplot synth4")
plt.xlabel("first component")
plt.ylabel("second component")
cl.clusterPlot(X4, clusters, centroids, Y4) 
plt.show()

# %% [markdown]
# If the single linkage method is used on the synth1 dataset the plot is really far left centered. The whole plot begins on the left and branches out to the right. In the average linkage method the center of the plot is still slightly to the left and branching out to the right but not so extreme as with the single linkage method. In the complete linkage method the plot is nearly centered in the middle and the branches are dividing evenly.

# %% [markdown]
# ## References
# 1. Tamara L Berg, Alexander C Berg, Jaety Edwards, and DA Forsyth. Who's in the
# picture. *Advances in Neural Information Processing Systems*, 17:137-144, 2005.
