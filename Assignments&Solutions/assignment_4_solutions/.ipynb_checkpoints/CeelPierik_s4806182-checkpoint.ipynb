# %% [markdown]
# Ceel Pierik - s4806182

# %% [markdown]
# # Assignment 4
#
# ## Objective of this assignment
# The objective of this exercise is to understand how the unsupervised learning methods $k$-means clustering and hierarchical clustering work. Upon completing the exercise you should also understand how the choice of number of clusters, distance metrics and linkage functions can impact the solutions obtained and further be able to interpret dendrograms and measures of cluster validity
#
# ## ** Important: ** When handing in your homework:
# + Hand in the notebook (and nothing else) named as follows: StudentName1_snumber_StudentName2_snumber.ipynb
# + Provide clear and complete answers to the questions below under a separate header (not hidden somewhere in your source code), and make sure to explain your answers / motivate your choices. Add Markdown cells where necessary.
# + Source code, output graphs, derivations, etc., should be included in the notebook.
# + Hand-in: upload to Blackboard.
# + Include name, student number, assignment (especially in filenames)!
# + When working in pairs only one of you should upload the assignment, and report the name of your partner in your filename.
# + For problems or questions: use the BB discussion board or email the student assistants.
#
#
# ## Advised Reading and Exercise Material
# **The following reading material is recommended:**
#
# - Pang-Ning Tan, Michael Steinbach, and Vipin Kumar, *Introduction to Data Mining*, section 8.1-8.3 and 8.5.7
#
#
# ## Additional Tools
# For this exercise you will need to load the provided *clusterPlot.py* and *clusterVal.py* scripts.
#
#
# ## Introduction
# In previous exercises we considered supervised learning, i.e., we were given both input data **X** and output values **Y**. We now move on to unsupervised learning where we are only provided input data **X**. The aim is here to find common patterns in the data such as groups of observations that are similar in some sense. In this exercise we will consider two clustering approaches for unsupervised learning: *k*-means clustering and hierarchical clustering.
#
#
# ## 4.1 *k*-means clustering
# In this part of the exercise we will investigate *k*-means clustering. In *k*-means each of the data points are assigned to the cluster in closest proximity according to some measure of distance between cluster centers and data points. When the distance is given by the squared euclidian distance, the centers are also called centroids. Once the data points have been assigned, each cluster center is updated to be placed at the center of the data points that are assigned to the cluster. This continues iteratively, usually until the assignment of data points to centers no longer changes or until a maximal number of iterations is reached.
#
# > 4.1.1a (1 point) Load the *synth1* data into python using the *loadmat* function. Cluster the data into *K = 4* clusters using the *k*-means algorithm. Make a scatter plot of the data and the clustering using the provided *clusterPlot()* function.
#  + *In Python, you can use the function k_means() from the package sklearn.cluster to compute *k*-means clustering.*
#  + *Type clusterPlot(X,clusters,centroids,y) to plot the data and the clustering. Don't forget to import the function from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
##Answer to question 4.1.1a
# %matplotlib inline  
import scipy.io as sio
from sklearn.cluster import k_means
import sys
sys.path.insert(0, './Toolbox')
import numpy as np
import matplotlib.pyplot as plt
import clusterPlot as plot
synth1 = sio.loadmat('Data/synth1.mat')
X1 = synth1['X']
y1 = synth1['y']
centroids, clusters, inertia = k_means(X1, n_clusters=4, random_state=0)
plot.clusterPlot(X1, clusters, centroids, y1)
plt.xlabel("X-coordinate")
plt.ylabel("Y-coordinate")
plt.title("Clusterplot of data from synth1")

# %% [markdown]
# > 4.1.1b (1 point) Try also to cluster and plot the data sets *synth2*, *synth3*, and *synth4* with the same number of *K*. Does the clustering coincide with the true classes? Explain for every data set.

# %%
##Answer to question 4.1.1b
synth2 = sio.loadmat('Data/synth2.mat')
X2 = synth2['X']
y2 = synth2['y']
centroids, clusters, inertia = k_means(X2, n_clusters=4, random_state=0)
plot.clusterPlot(X2, clusters, centroids, y2)
plt.xlabel("X-coordinate")
plt.ylabel("Y-coordinate")
plt.title("Clusterplot of data from synth2")

# %% [markdown]
# No, the clustering does not coincide with the true classes.
# The true classes are each aligned according to a certain linear equation, while the clusters cluster mainly based on x-value.

# %%
synth3 = sio.loadmat('Data/synth3.mat')
X3 = synth3['X']
y3 = synth3['y']
centroids, clusters, inertia = k_means(X3, n_clusters=4, random_state=0)
plot.clusterPlot(X3, clusters, centroids, y3)
plt.xlabel("X-coordinate")
plt.ylabel("Y-coordinate")
plt.title("Clusterplot of data from synth3")

# %% [markdown]
# No, the clustering does not coincide with the true classes.
# The true classes are each aligned according to a certain constant equation x = a, while the clusters cluster mainly based on y-value.

# %%
synth4 = sio.loadmat('Data/synth4.mat')
X4 = synth4['X']
y4 = synth4['y']
centroids, clusters, inertia = k_means(X4, n_clusters=4, random_state=0)
plot.clusterPlot(X4, clusters, centroids, y4)
plt.xlabel("X-coordinate")
plt.ylabel("Y-coordinate")
plt.title("Clusterplot of data from synth4")

# %% [markdown]
# Yes, the clustering does partially coincide with the true classes. However, since the true classes are not separated fully in the graph, the clustering is not perfect either.

# %% [markdown]
# Rather than using the error rate we will consider the supervised measures of cluster validity described in *Introduction to Data Mining* section 8.5.7, in particular the entropy, purity, rand statistic, and Jaccard coefficient. Carefully review these measures in the book and make sure you understand how they are calculated.
#
# > 4.1.2a (1 point) Repeat Exercise 4.1.1, but this time perform *k*-means clustering for *K = 1, ..., 10* clusters. For each value of *K* compute the four cluster validity measures mentioned above. Plot the cluster validity measures as a function of *K*
#  + *Use the clusterVal() function to compute the cluster validity. Don't forget to import it from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
##Answer to question 4.1.2a
import clusterVal as val

synth1 = sio.loadmat('Data/synth1.mat')
synth2 = sio.loadmat('Data/synth2.mat')
synth3 = sio.loadmat('Data/synth3.mat')
synth4 = sio.loadmat('Data/synth4.mat')

X1 = synth1['X']
y1 = synth1['y']
X2 = synth2['X']
y2 = synth2['y']
X3 = synth3['X']
y3 = synth3['y']
X4 = synth4['X']
y4 = synth4['y']

entropyArray1=[]
purityArray1=[]
randArray1=[]
jaccardArray1=[]
entropyArray2=[]
purityArray2=[]
randArray2=[]
jaccardArray2=[]
entropyArray3=[]
purityArray3=[]
randArray3=[]
jaccardArray3=[]
entropyArray4=[]
purityArray4=[]
randArray4=[]
jaccardArray4=[]

for i in range (1,11):
    centroids, clusters, inertia = k_means(X1, n_clusters=i, random_state=0)
    Entropy, Purity, Rand, Jaccard = val.clusterVal(y1, clusters);
    entropyArray1.append(Entropy)
    purityArray1.append(Purity)
    randArray1.append(Rand)
    jaccardArray1.append(Jaccard)
    
for i in range (1,11):
    centroids, clusters, inertia = k_means(X2, n_clusters=i, random_state=0)
    Entropy, Purity, Rand, Jaccard = val.clusterVal(y2, clusters);
    entropyArray2.append(Entropy)
    purityArray2.append(Purity)
    randArray2.append(Rand)
    jaccardArray2.append(Jaccard)
    
for i in range (1,11):
    centroids, clusters, inertia = k_means(X3, n_clusters=i, random_state=0)
    Entropy, Purity, Rand, Jaccard = val.clusterVal(y3, clusters);
    entropyArray3.append(Entropy)
    purityArray3.append(Purity)
    randArray3.append(Rand)
    jaccardArray3.append(Jaccard)

for i in range (1,11):
    centroids, clusters, inertia = k_means(X4, n_clusters=i, random_state=0)
    Entropy, Purity, Rand, Jaccard = val.clusterVal(y4, clusters);
    entropyArray4.append(Entropy)
    purityArray4.append(Purity)
    randArray4.append(Rand)
    jaccardArray4.append(Jaccard)
    
arrayOfArrays1=[entropyArray1, purityArray1, randArray1, jaccardArray1]
arrayOfArrays2=[entropyArray2, purityArray2, randArray2, jaccardArray2]
arrayOfArrays3=[entropyArray3, purityArray3, randArray3, jaccardArray3]
arrayOfArrays4=[entropyArray4, purityArray4, randArray4, jaccardArray4]

for j in range (0, 4):
    plt.plot(arrayOfArrays1[j])
    plt.title("Graph of scores plotted against the #clusters used in synth1")
    plt.ylabel("score")
    plt.xlabel("# clusters")
    plt.hold(True)
plt.show()
    
for j in range (0, 4):
    plt.plot(arrayOfArrays2[j])
    plt.title("Graph of scores plotted against the #clusters used in synth2")
    plt.ylabel("score")
    plt.xlabel("# clusters")
    plt.hold(True)
plt.show()
    
for j in range (0, 4):
    plt.plot(arrayOfArrays3[j])
    plt.title("Graph of scores plotted against the #clusters used in synth3")
    plt.ylabel("score")
    plt.xlabel("# clusters")
    plt.hold(True)
plt.show()
    
for j in range (0, 4):
    plt.plot(arrayOfArrays4[j])
    plt.title("Graph of scores plotted against the #clusters used in synth4")
    plt.ylabel(labels[j])
    plt.xlabel("# clusters")
    plt.hold(True)
plt.show()
# Out:
# F:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:77: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# F:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:85: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# F:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:93: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# F:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:101: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %% [markdown]
# > 4.1.2b (1 point) How can the cluster validity measures be used to select the best number of clusters?
# What happens when more than four clusters are used to model the data?

# %% [markdown]
# In general, we want the highest possible Jaccard, Rand and Purity score, and the lowest Entropy score. The best number of clusters is probably the one where taking one more cluster does not result in a substantial (enough) gain in scores. In general, classification measures get better with more clusters (even more than four) but the graph will flatten after a while; similarity measures will start to deteriorate when using more clusters than the optimal amount (this is best seen in the Jaccard score after 4 clusters).

# %% [markdown]
# *k*-means clustering has many different applications, one of which is data compression. A data set can be compressed by performing *k*-means clustering and then representing each data object by its cluster center. Thus, the only data that need to be stored are the *K* cluster centers and the *N* cluster indices.
#
# > 4.1.3a (1 point) We will consider a subset of the wild faces data described in berg2005[1]. Load the wildfaces data, *Data/wildfaces* using the *loadmat* function. Each data object is a $40 \times 40 \times 3 = 4800$ dimensional vector, corresponding to a 3-color $40 \times 40$ pixels image. Compute a *k*-means clustering of the data with *K = 10* clusters. Plot a few random images from the data set as well as their corresponding cluster centroids to see how they are represented.
# + You can plot an image by the command imshow(np.reshape(X[k,:],(c,x,y)).T) which reshapes an image vector to a 3-dimensional array and plots it. You can plot the cluster centroids in a similar manner.
# + Running *k*-means on a large data set can be slow. If you type k_means(X, K, verbose=True, max_iter=X, n_init=S) it will provide information about the iterations as they run. As before, n_init  constrains the number of initial repeated centroid seeds. Type help(kmeans) (or read the documentation) to read more about these options.

# %%
##Answer to question 4.1.3a
wildfaces = sio.loadmat('Data/wildfaces.mat')
X = wildfaces['X']  
centroids, clusters, inertia = k_means(X, n_clusters=10, random_state=0)
c=3
x=40
y=40



for k in range (0,10):
    plt.imshow(np.reshape(X[k,:],(c,x,y)).T)
    plt.ylabel("y")
    plt.xlabel("x")
    plt.title("an original picture")
    plt.show()
    plt.imshow(np.reshape(centroids[k,:],(c,x,y)).T)
    plt.ylabel("y")
    plt.xlabel("x")
    plt.title("cluster " + str(k+1))
    plt.show()

# %% [markdown]
# > 4.1.3b (1 point) How well is the data represented by the cluster centroids? Are you able to recognize the faces in the compressed representation? What happens if you increase or decrease the number of clusters?

# %%
##Answer to question 4.1.3b

# %% [markdown]
# *Double click to type your answer for 4.1.3b here:*
# The images created from the cluster centroids do, in a broad sense, get the shade of color right and you can still see that they are supposed to be faces. However, it does not feel like the faces represent the original faces in a good way. When I increase the number of clusters to 100, some of the original photos are clusters by themselves. When decreasing the amount of clusters to 5, the pictures get even more vague and do not seem to be representing much of anything anymore.

# %% [markdown]
# > 4.1.4a (1 point) Repeat the exercise with the digits data set. Load the digits data set from Data/digits. Each data object is a $16 \times 16 = 256$ dimensional vector, corresponding to a gray scale $16 \times 16$ pixels image.
# + You can change the color map to black-on-white gray-scale by adding the parameter cmap=cm.binary to the function imshow().

# %%
##Answer to question 4.1.4a
digits = sio.loadmat('Data/digits.mat')
X = digits['X']
n=10
centroids, clusters, inertia = k_means(X, n_clusters=n, random_state=0)

c=3
x=16
y=16
for k in range (0,n):
    plt.imshow(np.reshape(centroids[k,:],(x,y)))
    plt.ylabel("y")
    plt.xlabel("x")
    plt.title("Cluster " + str(k+1))
    plt.show()

# %% [markdown]
# > 4.1.4b (1 point) Why does running *k*-means with *K = 10* not give you 10 clusters corresponding to the 10 digits *0..9*? How many clusters do you need to visually represent the 10 different digits? Are there any digits that the clustering algorithm seems to confuse more than others and can you explain why?

# %%
##Answer to question 4.1.4b

# %% [markdown]
# *Double click to type your answer for 4.1.3b here:*
# Running k-means with K = 10 does not give 10 clusters corresponding to the 10 digits 0..9 because apparently different representations of certain numbers are differing more from each other than two different numbers do. In the case of K = 10, I do net get the number 5 as a cluster and I get the number 0 as a cluster twice, one which is very broad and the other more slender in shape. K = 13 is the lowest number that gives me a cluster that somewhat (albeit still quite ambiguously) represents the number 5 (while still having clusters for all the other ones as well). At K = 13 this number 5 could still be interpreted as number 3 as well. So the clustering algorithm seems to confuse numbers 3 and 5, and looking at the general vagueness of some clusters, 2 and 4 are hard as well.
#
# So it recognizes best: 1, 6, 7, 8, 9.
# It has a tough time deciding with 2, 3, 4, 5
# And it very easily sees different clusters in one number for: 0.

# %% [markdown]
# ## 4.2 Hierarchical Clustering
#
# In this part of the exercie we will consider hierarchical clustering based on the functions from the package *scipy.cluster.hierarchy*. The function *linkage()* forms a sample to sample distance matrix according to a given distance metric, and creates the linkages between data points forming the hierarchical cluster tree. The function *dendrogram* creates a plot of the generated tree. The function *fcluster* extracts the cluster from a linkage matrix w.r.t. a given criterion. Use *help* for the three functions (or read the online documentation) and inspect what distance metrics and linkage functions are implemented.
#
# > 4.2.1a (1 point) Load the data set from *Data/synth1*. Cluster the data using hierarchical clustering with single linkage using the Euclidean distance measure. Cluster the data into 4 clusters by cutting off the dendrogram at a threshold. Plot a dendrogram and a scatter plot of the clusters.
# + The function *linkage()* computes the hierarchical clustering, resulting in a matrix representing the hierarchy of clusterings. Type help(linkage) (or read the online documentation) to learn how to use it.
# + You can e.g. type *Z = linkage(X, method='single', metric='euclidean')* to use single linkage with the Euclidean distance measure.
# + To compute a clustering, you can use the function*fcluster()*. For example, type *cls = fcluster(Z, criterion='maxclust', t=4)* to get a maximum of 4 clusters. Type *help(fcluster)* (or read the online documentation) to learn more about what this function does.
# + To plot a dendrogram, you can use the *dendrogram()* function
# + Again, you can use the function *clusterplot()* to plot a scatter plot of the clustering.

# %%
##Answer to question 4.2.1a
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from matplotlib import pyplot as plt

synth1 = sio.loadmat('Data/synth1.mat')
X1 = synth1['X']
y1 = synth1['y']
Z = linkage(X1, method='single', metric='euclidean')
cls = fcluster(Z, criterion='maxclust', t=4)
fig = plt.figure()
dn = dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=4,  # show only the last p merged clusters
)
plt.xlabel("cluster (sizes)")
plt.ylabel("distances")
plt.title("'single' method dendrogram of synth1")
plt.show()

plot.clusterPlot(X1, cls, y=y1)
plt.xlabel("x")
plt.ylabel("y")
plt.title("clusterplot of synth1")
plt.show()

# %% [markdown]
# > 4.2.1b (1 point) Change the linkage methods (single, complete, average) and explain how this changes the dendrogram.
# Then plot a dendrogram and a scatterplot of the clusters for the *synth2*, *synth3*, and *synth4* data sets..

# %%
##Answer to question 4.2.1b
Z = linkage(X1, method='complete', metric='euclidean')
fig = plt.figure()
dn = dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=4,  # show only the last p merged clusters
)
plt.xlabel("cluster (sizes)")
plt.ylabel("distances")
plt.title("'complete' method dendrogram of synth1")
plt.show()

Z = linkage(X1, method='average', metric='euclidean')
fig = plt.figure()
dn = dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=4,  # show only the last p merged clusters
)
plt.xlabel("cluster (sizes)")
plt.ylabel("distances")
plt.title("'average' method dendrogram of synth1")
plt.show()

# %% [markdown]
# *Double click to type your answer for 4.2.1b here:*
# The simple method used in 4.2.1a seems to prefer starting clustering on the left side,
# while the average and complete methods seem to start clustering in the middle, creating more balanced trees.
# It seems as if the complete method tries to have the distance between a parent and both of its children equal,
# while this does not seem to be a priority for the average method.

# %%
synth2 = sio.loadmat('Data/synth2.mat')
synth3 = sio.loadmat('Data/synth3.mat')
synth4 = sio.loadmat('Data/synth4.mat')
X2 = synth2['X']
y2 = synth2['y']
X3 = synth3['X']
y3 = synth3['y']
X4 = synth4['X']
y4 = synth4['y']

Z = linkage(X2, method='single', metric='euclidean')
cls = fcluster(Z, criterion='maxclust', t=4)
fig = plt.figure()
dn = dendrogram(Z, truncate_mode='lastp', p=4)
plt.xlabel("cluster (sizes)")
plt.ylabel("distances")
plt.title("'single' method dendrogram of synth2")
plt.show()
plot.clusterPlot(X2, cls, y=y2)
plt.xlabel("x")
plt.ylabel("y")
plt.title("clusterplot of synth2")
plt.show()

Z = linkage(X3, method='single', metric='euclidean')
cls = fcluster(Z, criterion='maxclust', t=4)
fig = plt.figure()
dn = dendrogram(Z, truncate_mode='lastp', p=4)
plt.xlabel("cluster (sizes)")
plt.ylabel("distances")
plt.title("'single' method dendrogram of synth3")
plt.show()
plot.clusterPlot(X3, cls, y=y3)
plt.xlabel("x")
plt.ylabel("y")
plt.title("clusterplot of synth3")
plt.show()

Z = linkage(X4, method='single', metric='euclidean')
cls = fcluster(Z, criterion='maxclust', t=4)
fig = plt.figure()
dn = dendrogram(Z, truncate_mode='lastp', p=4)
plt.xlabel("cluster (sizes)")
plt.ylabel("distances")
plt.title("'single' method dendrogram of synth4")
plt.show()
plot.clusterPlot(X4, cls, y=y4)
plt.xlabel("x")
plt.ylabel("y")
plt.title("clusterplot of synth4")
plt.show()

# %% [markdown]
# ## References
# 1. Tamara L Berg, Alexander C Berg, Jaety Edwards, and DA Forsyth. Who's in the
# picture. *Advances in Neural Information Processing Systems*, 17:137-144, 2005.
