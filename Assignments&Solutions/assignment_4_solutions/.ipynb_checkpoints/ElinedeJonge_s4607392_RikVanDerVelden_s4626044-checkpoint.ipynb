# %% [markdown]
# # Assignment 4
#
# ## Objective of this assignment
# The objective of this exercise is to understand how the unsupervised learning methods $k$-means clustering and hierarchical clustering work. Upon completing the exercise you should also understand how the choice of number of clusters, distance metrics and linkage functions can impact the solutions obtained and further be able to interpret dendrograms and measures of cluster validity
#
# ## ** Important: ** When handing in your homework:
# + Hand in the notebook (and nothing else) named as follows: StudentName1_snumber_StudentName2_snumber.ipynb
# + Provide clear and complete answers to the questions below under a separate header (not hidden somewhere in your source code), and make sure to explain your answers / motivate your choices. Add Markdown cells where necessary.
# + Source code, output graphs, derivations, etc., should be included in the notebook.
# + Hand-in: upload to Blackboard.
# + Include name, student number, assignment (especially in filenames)!
# + When working in pairs only one of you should upload the assignment, and report the name of your partner in your filename.
# + For problems or questions: use the BB discussion board or email the student assistants.
#
#
# ## Advised Reading and Exercise Material
# **The following reading material is recommended:**
#
# - Pang-Ning Tan, Michael Steinbach, and Vipin Kumar, *Introduction to Data Mining*, section 8.1-8.3 and 8.5.7
#
#
# ## Additional Tools
# For this exercise you will need to load the provided *clusterPlot.py* and *clusterVal.py* scripts.
#
#
# ## Introduction
# In previous exercises we considered supervised learning, i.e., we were given both input data **X** and output values **Y**. We now move on to unsupervised learning where we are only provided input data **X**. The aim is here to find common patterns in the data such as groups of observations that are similar in some sense. In this exercise we will consider two clustering approaches for unsupervised learning: *k*-means clustering and hierarchical clustering.
#
#
# ## 4.1 *k*-means clustering
# In this part of the exercise we will investigate *k*-means clustering. In *k*-means each of the data points are assigned to the cluster in closest proximity according to some measure of distance between cluster centers and data points. When the distance is given by the squared euclidian distance, the centers are also called centroids. Once the data points have been assigned, each cluster center is updated to be placed at the center of the data points that are assigned to the cluster. This continues iteratively, usually until the assignment of data points to centers no longer changes or until a maximal number of iterations is reached.
#
# > 4.1.1a (1 point) Load the *synth1* data into python using the *loadmat* function. Cluster the data into *K = 4* clusters using the *k*-means algorithm. Make a scatter plot of the data and the clustering using the provided *clusterPlot()* function.
#  + *In Python, you can use the function k_means() from the package sklearn.cluster to compute *k*-means clustering.*
#  + *Type clusterPlot(X,clusters,centroids,y) to plot the data and the clustering. Don't forget to import the function from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
##Answer to question 4.1.1a
import scipy.io as sio
from sklearn.cluster import KMeans
from clusterPlot import clusterPlot
import matplotlib.pyplot as plt
# %matplotlib inline

X = sio.loadmat('synth1.mat')['X']
y = sio.loadmat('synth1.mat')['y']

kmeans = KMeans(n_clusters=4, random_state=0).fit(X)
clusters = kmeans.predict(X)
centroids = kmeans.cluster_centers_
fig = plt.figure(figsize=(10,10))
clusterPlot(X,clusters,centroids,y)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of Attribute A against Attribute B with classes Clustered from data set synth1")

# %% [markdown]
# > 4.1.1b (1 point) Try also to cluster and plot the data sets *synth2*, *synth3*, and *synth4* with the same number of *K*. Does the clustering coincide with the true classes? Explain for every data set.

# %%
##Answer to question 4.1.1b
X2 = sio.loadmat('synth2.mat')['X']
y2 = sio.loadmat('synth2.mat')['y']

X3 = sio.loadmat('synth3.mat')['X']
y3 = sio.loadmat('synth3.mat')['y']

X4 = sio.loadmat('synth4.mat')['X']
y4 = sio.loadmat('synth4.mat')['y']

kmeans2 = KMeans(n_clusters=4, random_state=0).fit(X2)
clusters2 = kmeans.predict(X2)
centroids2 = kmeans.cluster_centers_
fig = plt.figure(figsize=(10,10))
clusterPlot(X2,clusters,centroids,y2)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of Attribute A against Attribute B with classes Clustered from data set synth2")

kmeans3 = KMeans(n_clusters=4, random_state=0).fit(X3)
clusters3 = kmeans.predict(X3)
centroids3 = kmeans.cluster_centers_
fig = plt.figure(figsize=(10,10))
clusterPlot(X3,clusters,centroids,y3)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of Attribute A against Attribute B with classes Clustered from data set synth3")

kmeans4 = KMeans(n_clusters=4, random_state=0).fit(X4)
clusters4 = kmeans.predict(X4)
centroids4 = kmeans.cluster_centers_
fig = plt.figure(figsize=(10,10))
clusterPlot(X4,clusters,centroids,y4)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of Attribute A against Attribute B with classes Clustered from data set synth4")
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-25-e95015196f89> in <module>()
#      31 centroids4 = kmeans.cluster_centers_
#      32 fig = plt.figure(figsize=(10,10))
# ---> 33 clusterPlot(X4,clusters,centroids,y4)
#      34 plt.xlabel("Attribute A")
#      35 plt.ylabel("Attribute B")
#
# C:\Users\Rik\Documents\Assignment 4\Assignment_4\clusterPlot.py in clusterPlot(X, clusterid, centroids, y)
#      52                  zorder=2)
#      53     for i, cr in enumerate(np.unique(cls)):
# ---> 54         plt.plot(X[(cls == cr).ravel(), 0], X[(cls == cr).ravel(), 1], 'o',
#      55                  markersize=12, markeredgecolor=colors[i],
#      56                  markerfacecolor='None', markeredgewidth=3, zorder=1)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 1600 but corresponding boolean dimension is 200

# %% [markdown]
# *Double click to type your answer for 4.1.1b here:*
# The clustering of Synth2 and 3 certainly do not coincide with the true classes in the files. As far as 4 goes, it seems that there have been too many clusters assigned in this case. Synth 1 has been clustered reasonably accurately.

# %% [markdown]
# Rather than using the error rate we will consider the supervised measures of cluster validity described in *Introduction to Data Mining* section 8.5.7, in particular the entropy, purity, rand statistic, and Jaccard coefficient. Carefully review these measures in the book and make sure you understand how they are calculated.
#
# > 4.1.2a (1 point) Repeat Exercise 4.1.1, but this time perform *k*-means clustering for *K = 1, ..., 10* clusters. For each value of *K* compute the four cluster validity measures mentioned above. Plot the cluster validity measures as a function of *K*
#  + *Use the clusterVal() function to compute the cluster validity. Don't forget to import it from the Toolbox folder. If you are unsure about how to use the function, open the .py file in a text editor and take a look at documentation.*

# %%
##Answer to question 4.1.2a
from clusterVal import clusterVal
import numpy as np
Xarray = [X,X2,X3,X4]
yarray = [y,y2,y3,y4]
E = np.zeros((4,10))
P = np.zeros((4,10))
R = np.zeros((4,10))
J = np.zeros((4,10))

i=0
for i in range(0,4):
        for j in range (0, 10):
            ci = KMeans(n_clusters=j+1, random_state=0).fit_predict(Xarray[i])
            [Entropy, Purity, Rand, Jaccard] = clusterVal (yarray[i], ci )
            E[i,j] = Entropy
            P[i,j] = Purity
            R[i,j] = Rand
            J[i,j] = Jaccard
plt.figure()
plt.hold(True)
for p in range (0,4):
    plt.plot(range(1,11),E[p,:], label='Entropy')
    plt.plot(range(1,11),P[p,:], label='Purity')
    plt.plot(range(1,11),R[p,:], label='Rand')
    plt.plot(range(1,11),J[p,:], label='Jaccard')
    plt.xlabel("K values")
    plt.ylabel("Cluster validity")
    plt.title("Cluster validity for Synth"+str(p+1))
    plt.legend()
    plt.show()
# Out:
# R:\Anaconda2\lib\site-packages\ipykernel_launcher.py:21: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %% [markdown]
# > 4.1.2b (1 point) How can the cluster validity measures be used to select the best number of clusters?
# What happens when more than four clusters are used to model the data?

# %% [markdown]
# *Double click to type your answer for 4.1.2b here:*
# The validity measures are used to select the best number of clusters when the entropy is as low as possible and the purity, rand and Jaccard are as high as possible.
# When more than four clusters are used, overclustering will occur. This leads to data points being classified incorrectly.

# %% [markdown]
# *k*-means clustering has many different applications, one of which is data compression. A data set can be compressed by performing *k*-means clustering and then representing each data object by its cluster center. Thus, the only data that need to be stored are the *K* cluster centers and the *N* cluster indices.
#
# > 4.1.3a (1 point) We will consider a subset of the wild faces data described in berg2005[1]. Load the wildfaces data, *Data/wildfaces* using the *loadmat* function. Each data object is a $40 \times 40 \times 3 = 4800$ dimensional vector, corresponding to a 3-color $40 \times 40$ pixels image. Compute a *k*-means clustering of the data with *K = 10* clusters. Plot a few random images from the data set as well as their corresponding cluster centroids to see how they are represented.
# + You can plot an image by the command imshow(np.reshape(X[k,:],(c,x,y)).T) which reshapes an image vector to a 3-dimensional array and plots it. You can plot the cluster centroids in a similar manner.
# + Running *k*-means on a large data set can be slow. If you type k_means(X, K, verbose=True, max_iter=X, n_init=S) it will provide information about the iterations as they run. As before, n_init  constrains the number of initial repeated centroid seeds. Type help(kmeans) (or read the documentation) to read more about these options.

# %%
##Answer to question 4.1.3a
import random

X = sio.loadmat('wildfaces.mat')['X']

kmeans = KMeans(n_clusters=10, random_state=0).fit(X)
# kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
# kmeans = KMeans(n_clusters=96, random_state=0).fit(X)
# kmeans = KMeans(n_clusters=14, random_state=0).fit(X)
# kmeans = KMeans(n_clusters=23, random_state=0).fit(X)
Ci = kmeans.predict(X)
centroids = kmeans.cluster_centers_

indices = range(0,1000)
mylist = []

for i in range(0,5):
    mylist.append(random.choice(indices))

for k in mylist:
    plt.subplot(5,2,1), plt.imshow(np.reshape(X[k,:],(3,40,40)).T)
    plt.title("Image " + str(k) + " from dataset")
    plt.subplot(5,2,2), plt.imshow(np.reshape(centroids[Ci[k],:],(3,40,40)).T)
    plt.title("Corresponding cluster centroid")
    plt.show()

# %% [markdown]
# > 4.1.3b (1 point) How well is the data represented by the cluster centroids? Are you able to recognize the faces in the compressed representation? What happens if you increase or decrease the number of clusters?

# %%
##Answer to question 4.1.3b
##see answer to question 4.1.3a

# %% [markdown]
# *Double click to type your answer for 4.1.3b here:*
# The data is relatively well represented, the cluster centroids capture the essence of the pictures with moderate success. When increasing the number of clusters, the centroids will start to look more like the given image but it will decrease the usefulness of clustering. When decreasing the number of clusters, the centroids will no longer resemble the given images.

# %% [markdown]
# > 4.1.4a (1 point) Repeat the exercise with the digits data set. Load the digits data set from Data/digits. Each data object is a $16 \times 16 = 256$ dimensional vector, corresponding to a gray scale $16 \times 16$ pixels image.
# + You can change the color map to black-on-white gray-scale by adding the parameter cmap=cm.binary to the function imshow().

# %%
##Answer to question 4.1.4a
from matplotlib import cm
X = sio.loadmat('digits.mat')['X']
kmeans = KMeans(n_clusters=10, random_state=0).fit(X)
Ci = kmeans.predict(X)
centroids = kmeans.cluster_centers_

indices = range(0,9298)
mylist = []

for i in range(0,5):
    mylist.append(random.choice(indices))

for k in mylist:
    plt.subplot(5,2,1), plt.imshow(np.reshape(X[k,:],(16,16)),cmap=cm.binary)
    plt.title("Image " + str(k) + " from dataset")
    plt.subplot(5,2,2), plt.imshow(np.reshape(centroids[Ci[k],:],(16,16)),cmap=cm.binary)
    plt.title("Corresponding cluster centroid")
    plt.show()

# %% [markdown]
# > 4.1.4b (1 point) Why does running *k*-means with *K = 10* not give you 10 clusters corresponding to the 10 digits *0..9*? How many clusters do you need to visually represent the 10 different digits? Are there any digits that the clustering algorithm seems to confuse more than others and can you explain why?

# %%
##Answer to question 4.1.4b

# %% [markdown]
# *Double click to type your answer for 4.1.4b here:*
# There aren't 10 clusters corresponding with the 10 digits respectively. This is because K-means clusters the datapoints that are similar, but some digits datapoints are so dissimilar to eachother that K-means seperates them eventhough they are part of the same digit. And 2 digits'datapoints are so alike, that they are grouped in one cluster, while they actually belong to one digit and should be in the corresponding seperate cluster. So you do not need more clusters, but more accurate clustering. Some digits that can be confused by the clustering algorithm would be 0 & 6 and 3 & 8, because they are visually similar.

# %% [markdown]
# ## 4.2 Hierarchical Clustering
#
# In this part of the exercie we will consider hierarchical clustering based on the functions from the package *scipy.cluster.hierarchy*. The function *linkage()* forms a sample to sample distance matrix according to a given distance metric, and creates the linkages between data points forming the hierarchical cluster tree. The function *dendrogram* creates a plot of the generated tree. The function *fcluster* extracts the cluster from a linkage matrix w.r.t. a given criterion. Use *help* for the three functions (or read the online documentation) and inspect what distance metrics and linkage functions are implemented.
#
# > 4.2.1a (1 point) Load the data set from *Data/synth1*. Cluster the data using hierarchical clustering with single linkage using the Euclidean distance measure. Cluster the data into 4 clusters by cutting off the dendrogram at a threshold. Plot a dendrogram and a scatter plot of the clusters.
# + The function *linkage()* computes the hierarchical clustering, resulting in a matrix representing the hierarchy of clusterings. Type help(linkage) (or read the online documentation) to learn how to use it.
# + You can e.g. type *Z = linkage(X, method='single', metric='euclidean')* to use single linkage with the Euclidean distance measure.
# + To compute a clustering, you can use the function*fcluster()*. For example, type *cls = fcluster(Z, criterion='maxclust', t=4)* to get a maximum of 4 clusters. Type *help(fcluster)* (or read the online documentation) to learn more about what this function does.
# + To plot a dendrogram, you can use the *dendrogram()* function
# + Again, you can use the function *clusterplot()* to plot a scatter plot of the clustering.

# %%
##Answer to question 4.2.1a
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

X = sio.loadmat('synth1.mat')['X']
Z = linkage(X, method='single', metric='euclidean')
cls = fcluster(Z, criterion='maxclust', t=4)
fig = plt.figure(figsize=(30,40))
dendrogram(Z)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth1 with single linkage")
fig = plt.figure(figsize=(10,10))
clusterPlot(X,cls)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth1")
plt.show()

# %% [markdown]
# > 4.2.1b (1 point) Change the linkage methods (single, complete, average) and explain how this changes the dendrogram.
# Then plot a dendrogram and a scatterplot of the clusters for the *synth2*, *synth3*, and *synth4* data sets..

# %%
##Answer to question 4.2.1b
ZC = linkage(X, method='complete', metric='euclidean')
clsC = fcluster(ZC, criterion='maxclust', t=4)

ZA = linkage(X, method='average', metric='euclidean')
clsA = fcluster(ZA, criterion='maxclust', t=4)

fig = plt.figure(figsize=(50,30))
plt.subplot(1,2,1), dendrogram(ZC)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering with complete linkage")
plt.subplot(1,2,2), dendrogram(ZA)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering with average linkage")
plt.show()


X2 = sio.loadmat('synth2.mat')['X']
X3 = sio.loadmat('synth3.mat')['X']
X4 = sio.loadmat('synth4.mat')['X']
Z2S = linkage(X2, method='single', metric='euclidean')
Z3S = linkage(X3, method='single', metric='euclidean')
Z4S = linkage(X4, method='single', metric='euclidean')
Z2C = linkage(X2, method='complete', metric='euclidean')
Z3C = linkage(X3, method='complete', metric='euclidean')
Z4C = linkage(X4, method='complete', metric='euclidean')
Z2A = linkage(X2, method='average', metric='euclidean')
Z3A = linkage(X3, method='average', metric='euclidean')
Z4A = linkage(X4, method='average', metric='euclidean')
cls2S = fcluster(Z2S, criterion='maxclust', t=4)
cls2C = fcluster(Z2C, criterion='maxclust', t=4)
cls2A = fcluster(Z2A, criterion='maxclust', t=4)
cls3S = fcluster(Z3S, criterion='maxclust', t=4)
cls3C = fcluster(Z3C, criterion='maxclust', t=4)
cls3A = fcluster(Z3A, criterion='maxclust', t=4)
cls4S = fcluster(Z4S, criterion='maxclust', t=4)
cls4C = fcluster(Z4C, criterion='maxclust', t=4)
cls4A= fcluster(Z4A, criterion='maxclust', t=4)


fig = plt.figure(figsize=((90,60)))
plt.subplot(9,2,1), dendrogram(Z2S)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth2 with single linkage")
plt.subplot(9,2,2), clusterPlot(X2,cls2S)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth2")

plt.subplot(9,2,3), dendrogram(Z2C)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth2 with complete linkage")
plt.subplot(9,2,4), clusterPlot(X2,cls2C)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth2")

plt.subplot(9,2,5), dendrogram(Z2A)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth2 with average linkage")
plt.subplot(9,2,6), clusterPlot(X2,cls2A)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth2")

plt.subplot(9,2,7), dendrogram(Z3S)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth3 with single linkage")
plt.subplot(9,2,8), clusterPlot(X3,cls3S)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth3")

plt.subplot(9,2,9), dendrogram(Z3C)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth3 with complete linkage")
plt.subplot(9,2,10), clusterPlot(X3,cls3C)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth3")

plt.subplot(9,2,11), dendrogram(Z3A)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth3 with average linkage")
plt.subplot(9,2,12), clusterPlot(X3,cls3A)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth3")

plt.subplot(9,2,13), dendrogram(Z4S)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth4 with single linkage")
plt.subplot(9,2,14), clusterPlot(X4,cls4S)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth4")

plt.subplot(9,2,15), dendrogram(Z4C)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth4 with complete linkage")
plt.subplot(9,2,16), clusterPlot(X4,cls4C)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth4")

plt.subplot(9,2,17), dendrogram(Z4A)
plt.xlabel("Distance")
plt.ylabel("Data points")
plt.title("Dendrogram of the hierarchical clustering of Synth4 with average linkage")
plt.subplot(9,2,18), clusterPlot(X4,cls4A)
plt.xlabel("Attribute A")
plt.ylabel("Attribute B")
plt.title("Scatterplot of the hierarchical clustering of Synth4")

plt.show()

# %% [markdown]
# *Double click to type your answer for 4.1.3b here:*
# By changing the linkage methods, other clusters are made.

# %% [markdown]
# ## References
# 1. Tamara L Berg, Alexander C Berg, Jaety Edwards, and DA Forsyth. Who's in the
# picture. *Advances in Neural Information Processing Systems*, 17:137-144, 2005.
