# %% [markdown]
# # Assignment 5: Association mining
#
# ## Objective of this assignment
# The overall objective is to understand how frequent itemsets can be extracted by
# the Apriori algorithm and be able to calculate and interpret association rules in terms of support and confidence.
#
# ## ** Important: ** When handing in your homework:
# + Hand in the notebook (and nothing else) named as follows: StudentName1_snumber_StudentName2_snumber.ipynb
# + Provide clear and complete answers to the questions below under a separate header (not hidden somewhere in your source code), and make sure to explain your answers / motivate your choices. Add Markdown cells where necessary.
# + Source code, output graphs, derivations, etc., should be included in the notebook.
# + Hand-in: upload to Blackboard.
# + Include name, student number, assignment (especially in filenames)!
# + When working in pairs only one of you should upload the assignment, and report the name of your partner in your filename.
# + For problems or questions: use the BB discussion board or email the student assistants.
#
#
# ## Advised Reading and Exercise Material
# **The following reading material is recommended:**
#
# - Pang-Ning Tan, Michael Steinbach, and Vipin Kumar, *Introduction to Data Mining*, section 6.
#
#
# ## Additional Tools
# For this exercise you will need to load the provided *apriorimining.py* script.
#
#
# ##  5.1 Association mining for course data
# We will use the Apriori algorithm to automatically mine for associations. The Apriori algorithm is an adapted version of the script found here: https://github.com/nalinaksh/Association-Rule-Mining-Python
#
# Check out the script and doc and check if you understand how the association rules are computed.

# %%
import Toolbox.apriorimining
# Wouter Mobach - s44465733
# Victor van der Gevel - s4630807

# %% [markdown]
# #### 5.1.1
#
# (0 points) Look at the data file `Data/courses.txt` into Python. The data is represented in Table 1. Inspect the file Data/courses.txt and make sure you understand how the data in Table 1 is stored in the text file.
#
# ##### Table 1
# |#  |   History |Math| Biology| Spanish | Economics| Physics | Chemistry | English  |
# | :-------------: |:-------------:| :-----------:| :----------:| :------------:|:-------------:| :------------:|  :-------------: | :-------------: |
# |student 1 | 0| 1 | 0 | 0 | 1| 1 |1 |1
# |student 2 | 1| 1 | 1 | 0 | 0| 1 |1 |1
# |student 3 | 0| 1 | 0 | 1 | 0| 1 |0 |1
# |student 4 | 0| 0 | 1 | 0 | 0| 1 |1 |0
# |student 5 | 0| 1 | 0 | 0 | 0| 1 |1 |0
# |student 6 | 0| 1 | 1 | 0 | 0| 1 |1 |1

# %% [markdown]
# #### 5.1.2
# (1 point) We will analyze the data in Table 1 automatically using the function `associationmining.generate_association_rules()` from the script. Analyze the data with $ minsupport  \geq 80 \% $ and $ minconfidence \geq 100 \%$.What
# are the generated association rules? What kind of conclusions can you make based on these association rules about the subjects that students took?

# %%
import sys
sys.path.append('./Toolbox')
from apriorimining import generate_association_rules
generate_association_rules()
# Out:
# Please enter support value in %: 80
# Please enter confidence value in %: 100
# Enter the max number of rules you want to see (enter 0 to see all rules): 0
# Please enter filepath/filename and extension: Data/courses.txt
# ---------------TOP 10 FREQUENT 1-ITEMSET-------------------------
# set= { 6 },  sup= 100.0
# set= { 2 },  sup= 83.33
# set= { 7 },  sup= 83.33
# -----------------------------------------------------------------
# -------TOP 10 (or less) FREQUENT 2-ITEMSET------------------------
# set= { 2, 6 },  sup= 83.0
# set= { 6, 7 },  sup= 83.0
# ------------------------------------------------------------------
# ---------------------ASSOCIATION RULES------------------
# --------------------------------------------------------
# Rule #1: {  } ==> { 6 }, sup= 100.00, conf= 100.00
#
# Rule #2: { 2 } ==> { 6 }, sup= 83.33, conf= 100.00
#
# Rule #3: { 7 } ==> { 6 }, sup= 83.33, conf= 100.00
# --------------------------------------------------------

# %% [markdown]
# *Double click to type your answer for 5.1.2 here:*
# 100% of students took course 6, physics
# 83.33% of students took course 2, math
# 83.33% of students took course 7, chemistry
# There is a 83% association with courses 2 and 6, math and physics, these courses are often taken together.
# There is a 83% association with courses 6 and 7, physics and chemistry, these courses are often taken together.

# %% [markdown]
#   ##  5.2 Association mining for MovieLens data
#
#
#   In this part of the exercise we consider a Market Basket data set containing 943 users purchases of 1682 movies. A total of 100,000 movies
# have been purchased.The data set is called MovieLens100K and is provided by http://www.grouplens.org/node/73, see also the readme `MovieLensData.txt` in the data folder. The data currently considered is not the original data but modified for the apriori algorithm.
#
# #### 5.2.1
#   (0 points) The MovieLens data is stored in the file MovieLensData.txt. Inspect the file to see how the data is stored.
#
#
# #### 5.2.2
#   (1 point) Find association rules using the function below with $ minsupport  \geq 30 \% $ and $ minconfidence \geq 80 \%$. What are the associations with strongest confidence? Do these associations make sense? You can use file Data/u.item to print the movie titles in stead of numbers. If you enter filename `MovieLensData.txt`, the script will provide an additional option for this.

# %%
import sys
sys.path.append('./Toolbox')
from apriorimining import generate_association_rules
generate_association_rules()
# Out:
# Please enter support value in %: 30
# Please enter confidence value in %: 50
# Enter the max number of rules you want to see (enter 0 to see all rules): 0
# Please enter filepath/filename and extension: Data/MovieLensData.txt
# Do you want to print sets and rules with Movie names in stead of numbers? [y/n]: y
# ---------------TOP 10 FREQUENT 1-ITEMSET-------------------------
# set= { Star Wars (1977) },  sup= 61.82
# set= { Contact (1997) },  sup= 53.98
# set= { Fargo (1996) },  sup= 53.87
# set= { Return of the Jedi (1983) },  sup= 53.76
# set= { Liar Liar (1997) },  sup= 51.43
# set= { English Patient, The (1996) },  sup= 51.01
# set= { Scream (1996) },  sup= 50.69
# set= { Toy Story (1995) },  sup= 47.93
# set= { Air Force One (1997) },  sup= 45.71
# set= { Independence Day (ID4) (1996) },  sup= 45.49
# -----------------------------------------------------------------
# -------TOP 10 (or less) FREQUENT 2-ITEMSET------------------------
# set= { Return of the Jedi (1983), Star Wars (1977) },  sup= 50.0
# set= { Fargo (1996), Star Wars (1977) },  sup= 41.0
# set= { Star Wars (1977), Toy Story (1995) },  sup= 40.0
# set= { Raiders of the Lost Ark (1981), Star Wars (1977) },  sup= 40.0
# set= { Independence Day (ID4) (1996), Star Wars (1977) },  sup= 38.0
# set= { Godfather, The (1972), Star Wars (1977) },  sup= 37.0
# set= { Empire Strikes Back, The (1980), Star Wars (1977) },  sup= 36.0
# set= { Return of the Jedi (1983), Toy Story (1995) },  sup= 36.0
# set= { Fargo (1996), Return of the Jedi (1983) },  sup= 36.0
# set= { Raiders of the Lost Ark (1981), Return of the Jedi (1983) },  sup= 36.0
# ------------------------------------------------------------------
# -------TOP 10 (or less) FREQUENT 3-ITEMSET------------------------
# set= { Return of the Jedi (1983), Star Wars (1977), Toy Story (1995) },  sup= 35.0
# set= { Raiders of the Lost Ark (1981), Return of the Jedi (1983), Star Wars (1977) },  sup= 35.0
# set= { Independence Day (ID4) (1996), Return of the Jedi (1983), Star Wars (1977) },  sup= 34.0
# set= { Fargo (1996), Return of the Jedi (1983), Star Wars (1977) },  sup= 34.0
# set= { Empire Strikes Back, The (1980), Return of the Jedi (1983), Star Wars (1977) },  sup= 33.0
# set= { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981), Star Wars (1977) },  sup= 33.0
# set= { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981), Return of the Jedi (1983) },  sup= 31.0
# set= { Godfather, The (1972), Return of the Jedi (1983), Star Wars (1977) },  sup= 31.0
# set= { Return of the Jedi (1983), Silence of the Lambs, The (1991), Star Wars (1977) },  sup= 30.0
# set= { Return of the Jedi (1983), Star Wars (1977), Twelve Monkeys (1995) },  sup= 30.0
# ------------------------------------------------------------------
# -------TOP 10 (or less) FREQUENT 4-ITEMSET------------------------
# set= { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981), Return of the Jedi (1983), Star Wars (1977) },  sup= 31.0
# ------------------------------------------------------------------
# ---------------------ASSOCIATION RULES------------------
# --------------------------------------------------------
# Rule #228: { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 31.18, conf= 99.66
#
# Rule #140: { Empire Strikes Back, The (1980), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 33.40, conf= 99.37
#
# Rule #188: { Pulp Fiction (1994), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 30.22, conf= 98.62
#
# Rule #210: { Raiders of the Lost Ark (1981), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 35.74, conf= 98.54
#
# Rule #168: { Return of the Jedi (1983), Toy Story (1995) } ==> { Star Wars (1977) }, sup= 35.31, conf= 97.94
#
# Rule #157: { Return of the Jedi (1983), Silence of the Lambs, The (1991) } ==> { Star Wars (1977) }, sup= 30.65, conf= 97.64
#
# Rule #161: { Return of the Jedi (1983), Twelve Monkeys (1995) } ==> { Star Wars (1977) }, sup= 30.54, conf= 97.63
#
# Rule #198: { Godfather, The (1972), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 31.92, conf= 97.10
#
# Rule #173: { Return of the Jedi (1983), Star Trek: First Contact (1996) } ==> { Star Wars (1977) }, sup= 30.65, conf= 96.98
#
# Rule #144: { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981) } ==> { Star Wars (1977) }, sup= 33.51, conf= 96.64
#
# Rule #134: { Independence Day (ID4) (1996), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 34.68, conf= 96.46
#
# Rule #215: { Contact (1997), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 30.22, conf= 95.64
#
# Rule #184: { Fargo (1996), Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 34.99, conf= 95.38
#
# Rule #51: { Return of the Jedi (1983) } ==> { Star Wars (1977) }, sup= 50.90, conf= 94.67
#
# Rule #20: { Empire Strikes Back, The (1980) } ==> { Star Wars (1977) }, sup= 36.59, conf= 94.01
#
# Rule #204: { Raiders of the Lost Ark (1981), Silence of the Lambs, The (1991) } ==> { Star Wars (1977) }, sup= 30.86, conf= 93.57
#
# Rule #230: { Empire Strikes Back, The (1980), Return of the Jedi (1983), Star Wars (1977) } ==> { Raiders of the Lost Ark (1981) }, sup= 31.18, conf= 93.33
#
# Rule #151: { Empire Strikes Back, The (1980), Return of the Jedi (1983) } ==> { Raiders of the Lost Ark (1981) }, sup= 31.28, conf= 93.06
#
# Rule #227: { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 31.18, conf= 93.04
#
# Rule #222: { Empire Strikes Back, The (1980), Return of the Jedi (1983) } ==> { Raiders of the Lost Ark (1981), Star Wars (1977) }, sup= 31.18, conf= 92.74
#
# Rule #192: { Pulp Fiction (1994), Raiders of the Lost Ark (1981) } ==> { Star Wars (1977) }, sup= 30.65, conf= 92.04
#
# Rule #124: { Indiana Jones and the Last Crusade (1989) } ==> { Star Wars (1977) }, sup= 32.24, conf= 91.84
#
# Rule #145: { Empire Strikes Back, The (1980), Star Wars (1977) } ==> { Raiders of the Lost Ark (1981) }, sup= 33.51, conf= 91.59
#
# Rule #172: { Star Trek: First Contact (1996), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 30.65, conf= 91.46
#
# Rule #138: { Empire Strikes Back, The (1980), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 33.40, conf= 91.30
#
# Rule #17: { Mission: Impossible (1996) } ==> { Independence Day (ID4) (1996) }, sup= 33.30, conf= 91.28
#
# Rule #106: { Raiders of the Lost Ark (1981) } ==> { Star Wars (1977) }, sup= 40.30, conf= 90.48
#
# Rule #133: { Independence Day (ID4) (1996), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 34.68, conf= 90.33
#
# Rule #150: { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981) } ==> { Return of the Jedi (1983) }, sup= 31.28, conf= 90.21
#
# Rule #221: { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 31.18, conf= 89.91
#
# Rule #24: { Empire Strikes Back, The (1980) } ==> { Raiders of the Lost Ark (1981) }, sup= 34.68, conf= 89.10
#
# Rule #162: { Star Wars (1977), Twelve Monkeys (1995) } ==> { Return of the Jedi (1983) }, sup= 30.54, conf= 88.89
#
# Rule #211: { Raiders of the Lost Ark (1981), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 35.74, conf= 88.68
#
# Rule #18: { Forrest Gump (1994) } ==> { Star Wars (1977) }, sup= 30.12, conf= 88.47
#
# Rule #81: { Fugitive, The (1993) } ==> { Star Wars (1977) }, sup= 31.50, conf= 88.39
#
# Rule #31: { Back to the Future (1985) } ==> { Star Wars (1977) }, sup= 32.77, conf= 88.29
#
# Rule #100: { Princess Bride, The (1987) } ==> { Star Wars (1977) }, sup= 30.12, conf= 87.65
#
# Rule #193: { Pulp Fiction (1994), Star Wars (1977) } ==> { Raiders of the Lost Ark (1981) }, sup= 30.65, conf= 87.58
#
# Rule #167: { Star Wars (1977), Toy Story (1995) } ==> { Return of the Jedi (1983) }, sup= 35.31, conf= 87.40
#
# Rule #176: { Fargo (1996), Toy Story (1995) } ==> { Star Wars (1977) }, sup= 30.12, conf= 87.38
#
# Rule #128: { Indiana Jones and the Last Crusade (1989) } ==> { Raiders of the Lost Ark (1981) }, sup= 30.65, conf= 87.31
#
# Rule #229: { Raiders of the Lost Ark (1981), Return of the Jedi (1983), Star Wars (1977) } ==> { Empire Strikes Back, The (1980) }, sup= 31.18, conf= 87.24
#
# Rule #203: { Silence of the Lambs, The (1991), Star Wars (1977) } ==> { Raiders of the Lost Ark (1981) }, sup= 30.86, conf= 86.87
#
# Rule #111: { Star Trek: First Contact (1996) } ==> { Star Wars (1977) }, sup= 33.51, conf= 86.58
#
# Rule #97: { Godfather, The (1972) } ==> { Star Wars (1977) }, sup= 37.86, conf= 86.44
#
# Rule #22: { Empire Strikes Back, The (1980) } ==> { Return of the Jedi (1983) }, sup= 33.62, conf= 86.38
#
# Rule #189: { Pulp Fiction (1994), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 30.22, conf= 86.36
#
# Rule #156: { Silence of the Lambs, The (1991), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 30.65, conf= 86.27
#
# Rule #152: { Raiders of the Lost Ark (1981), Return of the Jedi (1983) } ==> { Empire Strikes Back, The (1980) }, sup= 31.28, conf= 86.26
#
# Rule #142: { Empire Strikes Back, The (1980) } ==> { Raiders of the Lost Ark (1981), Star Wars (1977) }, sup= 33.51, conf= 86.10
#
# Rule #224: { Raiders of the Lost Ark (1981), Return of the Jedi (1983) } ==> { Empire Strikes Back, The (1980), Star Wars (1977) }, sup= 31.18, conf= 85.96
#
# Rule #30: { Silence of the Lambs, The (1991) } ==> { Star Wars (1977) }, sup= 35.52, conf= 85.90
#
# Rule #137: { Empire Strikes Back, The (1980) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 33.40, conf= 85.83
#
# Rule #125: { Indiana Jones and the Last Crusade (1989) } ==> { Return of the Jedi (1983) }, sup= 30.01, conf= 85.50
#
# Rule #216: { Contact (1997), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 30.22, conf= 85.33
#
# Rule #226: { Empire Strikes Back, The (1980), Star Wars (1977) } ==> { Raiders of the Lost Ark (1981), Return of the Jedi (1983) }, sup= 31.18, conf= 85.22
#
# Rule #35: { Back to the Future (1985) } ==> { Raiders of the Lost Ark (1981) }, sup= 31.60, conf= 85.14
#
# Rule #83: { Fugitive, The (1993) } ==> { Raiders of the Lost Ark (1981) }, sup= 30.33, conf= 85.12
#
# Rule #10: { Independence Day (ID4) (1996) } ==> { Star Wars (1977) }, sup= 38.39, conf= 84.38
#
# Rule #200: { Godfather, The (1972), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 31.92, conf= 84.31
#
# Rule #112: { Mission: Impossible (1996) } ==> { Star Wars (1977) }, sup= 30.75, conf= 84.30
#
# Rule #44: { Toy Story (1995) } ==> { Star Wars (1977) }, sup= 40.40, conf= 84.29
#
# Rule #91: { Pulp Fiction (1994) } ==> { Star Wars (1977) }, sup= 34.99, conf= 83.76
#
# Rule #183: { Fargo (1996), Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 34.99, conf= 83.76
#
# Rule #146: { Raiders of the Lost Ark (1981), Star Wars (1977) } ==> { Empire Strikes Back, The (1980) }, sup= 33.51, conf= 83.16
#
# Rule #42: { Twelve Monkeys (1995) } ==> { Star Wars (1977) }, sup= 34.36, conf= 82.65
#
# Rule #38: { Rock, The (1996) } ==> { Star Wars (1977) }, sup= 33.09, conf= 82.54
#
# Rule #50: { Star Wars (1977) } ==> { Return of the Jedi (1983) }, sup= 50.90, conf= 82.33
#
# Rule #33: { Back to the Future (1985) } ==> { Return of the Jedi (1983) }, sup= 30.33, conf= 81.71
#
# Rule #56: { Star Trek: First Contact (1996) } ==> { Return of the Jedi (1983) }, sup= 31.60, conf= 81.64
#
# Rule #77: { Twelve Monkeys (1995) } ==> { Fargo (1996) }, sup= 33.93, conf= 81.63
#
# Rule #108: { Raiders of the Lost Ark (1981) } ==> { Return of the Jedi (1983) }, sup= 36.27, conf= 81.43
#
# Rule #149: { Empire Strikes Back, The (1980) } ==> { Raiders of the Lost Ark (1981), Return of the Jedi (1983) }, sup= 31.28, conf= 80.38
#
# Rule #206: { Raiders of the Lost Ark (1981) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 35.74, conf= 80.24
#
# Rule #219: { Empire Strikes Back, The (1980) } ==> { Raiders of the Lost Ark (1981), Return of the Jedi (1983), Star Wars (1977) }, sup= 31.18, conf= 80.11
#
# Rule #105: { Silence of the Lambs, The (1991) } ==> { Raiders of the Lost Ark (1981) }, sup= 32.98, conf= 79.74
#
# Rule #95: { Pulp Fiction (1994) } ==> { Raiders of the Lost Ark (1981) }, sup= 33.30, conf= 79.70
#
# Rule #169: { Star Trek: First Contact (1996) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 30.65, conf= 79.18
#
# Rule #9: { Rock, The (1996) } ==> { Independence Day (ID4) (1996) }, sup= 31.71, conf= 79.10
#
# Rule #12: { Independence Day (ID4) (1996) } ==> { Return of the Jedi (1983) }, sup= 35.95, conf= 79.02
#
# Rule #23: { Raiders of the Lost Ark (1981) } ==> { Empire Strikes Back, The (1980) }, sup= 34.68, conf= 77.86
#
# Rule #64: { Fargo (1996) } ==> { Star Wars (1977) }, sup= 41.78, conf= 77.56
#
# Rule #48: { Rock, The (1996) } ==> { Return of the Jedi (1983) }, sup= 31.07, conf= 77.51
#
# Rule #225: { Raiders of the Lost Ark (1981), Star Wars (1977) } ==> { Empire Strikes Back, The (1980), Return of the Jedi (1983) }, sup= 31.18, conf= 77.37
#
# Rule #89: { Silence of the Lambs, The (1991) } ==> { Pulp Fiction (1994) }, sup= 31.92, conf= 77.18
#
# Rule #103: { Jerry Maguire (1996) } ==> { Star Wars (1977) }, sup= 31.39, conf= 77.08
#
# Rule #205: { Raiders of the Lost Ark (1981), Star Wars (1977) } ==> { Silence of the Lambs, The (1991) }, sup= 30.86, conf= 76.58
#
# Rule #40: { Rock, The (1996) } ==> { Toy Story (1995) }, sup= 30.65, conf= 76.46
#
# Rule #88: { Pulp Fiction (1994) } ==> { Silence of the Lambs, The (1991) }, sup= 31.92, conf= 76.40
#
# Rule #73: { Jerry Maguire (1996) } ==> { Fargo (1996) }, sup= 31.07, conf= 76.30
#
# Rule #129: { Independence Day (ID4) (1996) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 34.68, conf= 76.22
#
# Rule #194: { Raiders of the Lost Ark (1981), Star Wars (1977) } ==> { Pulp Fiction (1994) }, sup= 30.65, conf= 76.05
#
# Rule #46: { Silence of the Lambs, The (1991) } ==> { Return of the Jedi (1983) }, sup= 31.39, conf= 75.90
#
# Rule #52: { Twelve Monkeys (1995) } ==> { Return of the Jedi (1983) }, sup= 31.28, conf= 75.26
#
# Rule #141: { Raiders of the Lost Ark (1981) } ==> { Empire Strikes Back, The (1980), Star Wars (1977) }, sup= 33.51, conf= 75.24
#
# Rule #55: { Toy Story (1995) } ==> { Return of the Jedi (1983) }, sup= 36.06, conf= 75.22
#
# Rule #63: { Rock, The (1996) } ==> { Fargo (1996) }, sup= 30.12, conf= 75.13
#
# Rule #98: { Godfather, The (1972) } ==> { Return of the Jedi (1983) }, sup= 32.87, conf= 75.06
#
# Rule #94: { Raiders of the Lost Ark (1981) } ==> { Pulp Fiction (1994) }, sup= 33.30, conf= 74.76
#
# Rule #202: { Silence of the Lambs, The (1991) } ==> { Raiders of the Lost Ark (1981), Star Wars (1977) }, sup= 30.86, conf= 74.62
#
# Rule #177: { Star Wars (1977), Toy Story (1995) } ==> { Fargo (1996) }, sup= 30.12, conf= 74.54
#
# Rule #61: { Silence of the Lambs, The (1991) } ==> { Fargo (1996) }, sup= 30.75, conf= 74.36
#
# Rule #69: { Pulp Fiction (1994) } ==> { Fargo (1996) }, sup= 30.97, conf= 74.11
#
# Rule #154: { Silence of the Lambs, The (1991) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 30.65, conf= 74.10
#
# Rule #104: { Raiders of the Lost Ark (1981) } ==> { Silence of the Lambs, The (1991) }, sup= 32.98, conf= 74.05
#
# Rule #165: { Toy Story (1995) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 35.31, conf= 73.67
#
# Rule #158: { Twelve Monkeys (1995) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 30.54, conf= 73.47
#
# Rule #92: { Pulp Fiction (1994) } ==> { Return of the Jedi (1983) }, sup= 30.65, conf= 73.35
#
# Rule #191: { Pulp Fiction (1994) } ==> { Raiders of the Lost Ark (1981), Star Wars (1977) }, sup= 30.65, conf= 73.35
#
# Rule #14: { Independence Day (ID4) (1996) } ==> { Toy Story (1995) }, sup= 33.30, conf= 73.19
#
# Rule #16: { Independence Day (ID4) (1996) } ==> { Mission: Impossible (1996) }, sup= 33.30, conf= 73.19
#
# Rule #196: { Godfather, The (1972) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 31.92, conf= 72.88
#
# Rule #185: { Pulp Fiction (1994) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 30.22, conf= 72.34
#
# Rule #59: { Independence Day (ID4) (1996) } ==> { Fargo (1996) }, sup= 32.87, conf= 72.26
#
# Rule #178: { Fargo (1996), Star Wars (1977) } ==> { Toy Story (1995) }, sup= 30.12, conf= 72.08
#
# Rule #79: { Toy Story (1995) } ==> { Fargo (1996) }, sup= 34.46, conf= 71.90
#
# Rule #71: { Godfather, The (1972) } ==> { Fargo (1996) }, sup= 31.39, conf= 71.67
#
# Rule #36: { Raiders of the Lost Ark (1981) } ==> { Back to the Future (1985) }, sup= 31.60, conf= 70.95
#
# Rule #28: { Air Force One (1997) } ==> { Contact (1997) }, sup= 32.24, conf= 70.53
#
# Rule #147: { Raiders of the Lost Ark (1981) } ==> { Empire Strikes Back, The (1980), Return of the Jedi (1983) }, sup= 31.28, conf= 70.24
#
# Rule #209: { Return of the Jedi (1983), Star Wars (1977) } ==> { Raiders of the Lost Ark (1981) }, sup= 35.74, conf= 70.21
#
# Rule #217: { Raiders of the Lost Ark (1981) } ==> { Empire Strikes Back, The (1980), Return of the Jedi (1983), Star Wars (1977) }, sup= 31.18, conf= 70.00
#
# Rule #8: { Independence Day (ID4) (1996) } ==> { Rock, The (1996) }, sup= 31.71, conf= 69.70
#
# Rule #15: { Toy Story (1995) } ==> { Independence Day (ID4) (1996) }, sup= 33.30, conf= 69.47
#
# Rule #166: { Return of the Jedi (1983), Star Wars (1977) } ==> { Toy Story (1995) }, sup= 35.31, conf= 69.38
#
# Rule #201: { Raiders of the Lost Ark (1981) } ==> { Silence of the Lambs, The (1991), Star Wars (1977) }, sup= 30.86, conf= 69.29
#
# Rule #127: { Raiders of the Lost Ark (1981) } ==> { Indiana Jones and the Last Crusade (1989) }, sup= 30.65, conf= 68.81
#
# Rule #190: { Raiders of the Lost Ark (1981) } ==> { Pulp Fiction (1994), Star Wars (1977) }, sup= 30.65, conf= 68.81
#
# Rule #182: { Return of the Jedi (1983), Star Wars (1977) } ==> { Fargo (1996) }, sup= 34.99, conf= 68.75
#
# Rule #75: { Raiders of the Lost Ark (1981) } ==> { Fargo (1996) }, sup= 30.43, conf= 68.33
#
# Rule #67: { Return of the Jedi (1983) } ==> { Fargo (1996) }, sup= 36.69, conf= 68.24
#
# Rule #132: { Return of the Jedi (1983), Star Wars (1977) } ==> { Independence Day (ID4) (1996) }, sup= 34.68, conf= 68.12
#
# Rule #66: { Fargo (1996) } ==> { Return of the Jedi (1983) }, sup= 36.69, conf= 68.11
#
# Rule #82: { Raiders of the Lost Ark (1981) } ==> { Fugitive, The (1993) }, sup= 30.33, conf= 68.10
#
# Rule #65: { Star Wars (1977) } ==> { Fargo (1996) }, sup= 41.78, conf= 67.58
#
# Rule #109: { Return of the Jedi (1983) } ==> { Raiders of the Lost Ark (1981) }, sup= 36.27, conf= 67.46
#
# Rule #54: { Return of the Jedi (1983) } ==> { Toy Story (1995) }, sup= 36.06, conf= 67.06
#
# Rule #13: { Return of the Jedi (1983) } ==> { Independence Day (ID4) (1996) }, sup= 35.95, conf= 66.86
#
# Rule #207: { Return of the Jedi (1983) } ==> { Raiders of the Lost Ark (1981), Star Wars (1977) }, sup= 35.74, conf= 66.47
#
# Rule #26: { Air Force One (1997) } ==> { Liar Liar (1997) }, sup= 30.22, conf= 66.13
#
# Rule #164: { Return of the Jedi (1983) } ==> { Star Wars (1977), Toy Story (1995) }, sup= 35.31, conf= 65.68
#
# Rule #139: { Return of the Jedi (1983), Star Wars (1977) } ==> { Empire Strikes Back, The (1980) }, sup= 33.40, conf= 65.62
#
# Rule #116: { Contact (1997) } ==> { Star Wars (1977) }, sup= 35.42, conf= 65.62
#
# Rule #43: { Star Wars (1977) } ==> { Toy Story (1995) }, sup= 40.40, conf= 65.35
#
# Rule #107: { Star Wars (1977) } ==> { Raiders of the Lost Ark (1981) }, sup= 40.30, conf= 65.18
#
# Rule #181: { Return of the Jedi (1983) } ==> { Fargo (1996), Star Wars (1977) }, sup= 34.99, conf= 65.09
#
# Rule #179: { Fargo (1996) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 34.99, conf= 64.96
#
# Rule #131: { Return of the Jedi (1983) } ==> { Independence Day (ID4) (1996), Star Wars (1977) }, sup= 34.68, conf= 64.50
#
# Rule #87: { Scream (1996) } ==> { Liar Liar (1997) }, sup= 32.66, conf= 64.44
#
# Rule #78: { Fargo (1996) } ==> { Toy Story (1995) }, sup= 34.46, conf= 63.98
#
# Rule #39: { Toy Story (1995) } ==> { Rock, The (1996) }, sup= 30.65, conf= 63.94
#
# Rule #119: { Liar Liar (1997) } ==> { Contact (1997) }, sup= 32.87, conf= 63.92
#
# Rule #122: { Scream (1996) } ==> { Contact (1997) }, sup= 32.34, conf= 63.81
#
# Rule #84: { Liar Liar (1997) } ==> { Star Wars (1977) }, sup= 32.77, conf= 63.71
#
# Rule #86: { Liar Liar (1997) } ==> { Scream (1996) }, sup= 32.66, conf= 63.51
#
# Rule #76: { Fargo (1996) } ==> { Twelve Monkeys (1995) }, sup= 33.93, conf= 62.99
#
# Rule #175: { Toy Story (1995) } ==> { Fargo (1996), Star Wars (1977) }, sup= 30.12, conf= 62.83
#
# Rule #199: { Return of the Jedi (1983), Star Wars (1977) } ==> { Godfather, The (1972) }, sup= 31.92, conf= 62.71
#
# Rule #21: { Return of the Jedi (1983) } ==> { Empire Strikes Back, The (1980) }, sup= 33.62, conf= 62.52
#
# Rule #113: { English Patient, The (1996) } ==> { Contact (1997) }, sup= 31.81, conf= 62.37
#
# Rule #136: { Return of the Jedi (1983) } ==> { Empire Strikes Back, The (1980), Star Wars (1977) }, sup= 33.40, conf= 62.13
#
# Rule #11: { Star Wars (1977) } ==> { Independence Day (ID4) (1996) }, sup= 38.39, conf= 62.09
#
# Rule #2: {  } ==> { Star Wars (1977) }, sup= 61.82, conf= 61.82
#
# Rule #223: { Return of the Jedi (1983), Star Wars (1977) } ==> { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981) }, sup= 31.18, conf= 61.25
#
# Rule #96: { Star Wars (1977) } ==> { Godfather, The (1972) }, sup= 37.86, conf= 61.23
#
# Rule #99: { Return of the Jedi (1983) } ==> { Godfather, The (1972) }, sup= 32.87, conf= 61.14
#
# Rule #58: { Fargo (1996) } ==> { Independence Day (ID4) (1996) }, sup= 32.87, conf= 61.02
#
# Rule #120: { Contact (1997) } ==> { Liar Liar (1997) }, sup= 32.87, conf= 60.90
#
# Rule #155: { Return of the Jedi (1983), Star Wars (1977) } ==> { Silence of the Lambs, The (1991) }, sup= 30.65, conf= 60.21
#
# Rule #171: { Return of the Jedi (1983), Star Wars (1977) } ==> { Star Trek: First Contact (1996) }, sup= 30.65, conf= 60.21
#
# Rule #160: { Return of the Jedi (1983), Star Wars (1977) } ==> { Twelve Monkeys (1995) }, sup= 30.54, conf= 60.00
#
# Rule #121: { Contact (1997) } ==> { Scream (1996) }, sup= 32.34, conf= 59.92
#
# Rule #27: { Contact (1997) } ==> { Air Force One (1997) }, sup= 32.24, conf= 59.72
#
# Rule #187: { Return of the Jedi (1983), Star Wars (1977) } ==> { Pulp Fiction (1994) }, sup= 30.22, conf= 59.38
#
# Rule #214: { Return of the Jedi (1983), Star Wars (1977) } ==> { Contact (1997) }, sup= 30.22, conf= 59.38
#
# Rule #197: { Return of the Jedi (1983) } ==> { Godfather, The (1972), Star Wars (1977) }, sup= 31.92, conf= 59.37
#
# Rule #101: { Scream (1996) } ==> { Star Wars (1977) }, sup= 30.01, conf= 59.21
#
# Rule #19: { Star Wars (1977) } ==> { Empire Strikes Back, The (1980) }, sup= 36.59, conf= 59.18
#
# Rule #114: { Contact (1997) } ==> { English Patient, The (1996) }, sup= 31.81, conf= 58.94
#
# Rule #57: { Return of the Jedi (1983) } ==> { Star Trek: First Contact (1996) }, sup= 31.60, conf= 58.78
#
# Rule #118: { Return of the Jedi (1983) } ==> { Contact (1997) }, sup= 31.60, conf= 58.78
#
# Rule #25: { Liar Liar (1997) } ==> { Air Force One (1997) }, sup= 30.22, conf= 58.76
#
# Rule #117: { Contact (1997) } ==> { Return of the Jedi (1983) }, sup= 31.60, conf= 58.55
#
# Rule #45: { Return of the Jedi (1983) } ==> { Silence of the Lambs, The (1991) }, sup= 31.39, conf= 58.38
#
# Rule #70: { Fargo (1996) } ==> { Godfather, The (1972) }, sup= 31.39, conf= 58.27
#
# Rule #53: { Return of the Jedi (1983) } ==> { Twelve Monkeys (1995) }, sup= 31.28, conf= 58.19
#
# Rule #148: { Return of the Jedi (1983) } ==> { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981) }, sup= 31.28, conf= 58.19
#
# Rule #218: { Return of the Jedi (1983) } ==> { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981), Star Wars (1977) }, sup= 31.18, conf= 57.99
#
# Rule #208: { Star Wars (1977) } ==> { Raiders of the Lost Ark (1981), Return of the Jedi (1983) }, sup= 35.74, conf= 57.80
#
# Rule #47: { Return of the Jedi (1983) } ==> { Rock, The (1996) }, sup= 31.07, conf= 57.79
#
# Rule #72: { Fargo (1996) } ==> { Jerry Maguire (1996) }, sup= 31.07, conf= 57.68
#
# Rule #68: { Fargo (1996) } ==> { Pulp Fiction (1994) }, sup= 30.97, conf= 57.48
#
# Rule #29: { Star Wars (1977) } ==> { Silence of the Lambs, The (1991) }, sup= 35.52, conf= 57.46
#
# Rule #115: { Star Wars (1977) } ==> { Contact (1997) }, sup= 35.42, conf= 57.29
#
# Rule #163: { Star Wars (1977) } ==> { Return of the Jedi (1983), Toy Story (1995) }, sup= 35.31, conf= 57.12
#
# Rule #60: { Fargo (1996) } ==> { Silence of the Lambs, The (1991) }, sup= 30.75, conf= 57.09
#
# Rule #93: { Return of the Jedi (1983) } ==> { Pulp Fiction (1994) }, sup= 30.65, conf= 57.00
#
# Rule #153: { Return of the Jedi (1983) } ==> { Silence of the Lambs, The (1991), Star Wars (1977) }, sup= 30.65, conf= 57.00
#
# Rule #170: { Return of the Jedi (1983) } ==> { Star Trek: First Contact (1996), Star Wars (1977) }, sup= 30.65, conf= 57.00
#
# Rule #159: { Return of the Jedi (1983) } ==> { Star Wars (1977), Twelve Monkeys (1995) }, sup= 30.54, conf= 56.80
#
# Rule #90: { Star Wars (1977) } ==> { Pulp Fiction (1994) }, sup= 34.99, conf= 56.60
#
# Rule #180: { Star Wars (1977) } ==> { Fargo (1996), Return of the Jedi (1983) }, sup= 34.99, conf= 56.60
#
# Rule #74: { Fargo (1996) } ==> { Raiders of the Lost Ark (1981) }, sup= 30.43, conf= 56.50
#
# Rule #34: { Return of the Jedi (1983) } ==> { Back to the Future (1985) }, sup= 30.33, conf= 56.41
#
# Rule #186: { Return of the Jedi (1983) } ==> { Pulp Fiction (1994), Star Wars (1977) }, sup= 30.22, conf= 56.21
#
# Rule #213: { Return of the Jedi (1983) } ==> { Contact (1997), Star Wars (1977) }, sup= 30.22, conf= 56.21
#
# Rule #130: { Star Wars (1977) } ==> { Independence Day (ID4) (1996), Return of the Jedi (1983) }, sup= 34.68, conf= 56.09
#
# Rule #212: { Contact (1997) } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 30.22, conf= 55.99
#
# Rule #62: { Fargo (1996) } ==> { Rock, The (1996) }, sup= 30.12, conf= 55.91
#
# Rule #174: { Fargo (1996) } ==> { Star Wars (1977), Toy Story (1995) }, sup= 30.12, conf= 55.91
#
# Rule #126: { Return of the Jedi (1983) } ==> { Indiana Jones and the Last Crusade (1989) }, sup= 30.01, conf= 55.82
#
# Rule #41: { Star Wars (1977) } ==> { Twelve Monkeys (1995) }, sup= 34.36, conf= 55.57
#
# Rule #110: { Star Wars (1977) } ==> { Star Trek: First Contact (1996) }, sup= 33.51, conf= 54.20
#
# Rule #143: { Star Wars (1977) } ==> { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981) }, sup= 33.51, conf= 54.20
#
# Rule #135: { Star Wars (1977) } ==> { Empire Strikes Back, The (1980), Return of the Jedi (1983) }, sup= 33.40, conf= 54.03
#
# Rule #7: {  } ==> { Contact (1997) }, sup= 53.98, conf= 53.98
#
# Rule #4: {  } ==> { Fargo (1996) }, sup= 53.87, conf= 53.87
#
# Rule #3: {  } ==> { Return of the Jedi (1983) }, sup= 53.76, conf= 53.76
#
# Rule #37: { Star Wars (1977) } ==> { Rock, The (1996) }, sup= 33.09, conf= 53.52
#
# Rule #32: { Star Wars (1977) } ==> { Back to the Future (1985) }, sup= 32.77, conf= 53.00
#
# Rule #85: { Star Wars (1977) } ==> { Liar Liar (1997) }, sup= 32.77, conf= 53.00
#
# Rule #123: { Star Wars (1977) } ==> { Indiana Jones and the Last Crusade (1989) }, sup= 32.24, conf= 52.14
#
# Rule #195: { Star Wars (1977) } ==> { Godfather, The (1972), Return of the Jedi (1983) }, sup= 31.92, conf= 51.63
#
# Rule #5: {  } ==> { Liar Liar (1997) }, sup= 51.43, conf= 51.43
#
# Rule #1: {  } ==> { English Patient, The (1996) }, sup= 51.01, conf= 51.01
#
# Rule #80: { Star Wars (1977) } ==> { Fugitive, The (1993) }, sup= 31.50, conf= 50.94
#
# Rule #49: {  } ==> { Return of the Jedi (1983), Star Wars (1977) }, sup= 50.90, conf= 50.90
#
# Rule #102: { Star Wars (1977) } ==> { Jerry Maguire (1996) }, sup= 31.39, conf= 50.77
#
# Rule #6: {  } ==> { Scream (1996) }, sup= 50.69, conf= 50.69
#
# Rule #220: { Star Wars (1977) } ==> { Empire Strikes Back, The (1980), Raiders of the Lost Ark (1981), Return of the Jedi (1983) }, sup= 31.18, conf= 50.43
# --------------------------------------------------------

# %% [markdown]
# *Double click to type your answer for 5.2.2 here:*
# The associations with the strongest confidence are for the movie Star Wars. For instance in rule 228 there is the highest confidence of 99.66 that people that have purchased 'Empire Stikes Back', 'Raiders of the Lost Ark' and 'The Return of the Jedi' will also purchase 'Star Wars'. These associations make sense because 'Empire Stikes Back' and 'The Return of the Jedi' are both Star Wars movies so someone who is interested in Star Wars will be likely to purchase all movies related to the franchise. Furthermore, all four of the movies in the association rule are very popular so they are likely to be purchased.

# %% [markdown]
# #### 5.2.3
# (1 point) Which movie has been bought by the most users? There are only few rules with more than three items. Why?

# %% [markdown]
# *Double click to type your answer for 5.2.3 here:*
# The movie that has been bought the most is 'Star Wars' with support = 61.82.
# There is only one rule with more than three items because people dont tend to buy more than three items.

# %% [markdown]
# #### 5.2.4
# (0.5 points) Often we are interested in rules with high confidence. Is it possible for
# itemsets to have very low support but still have a very high confidence?

# %% [markdown]
# *Double click to type your answer for 5.2.4 here:*
# Most rules with a very high confidence have a support in range of 30 - 35. This range or a higher one can also be seen in rules with a lower confidence. Thus it is possible for itemsets to have a relatively low support but still have a high confidence.

# %% [markdown]
# ## 5.3 Calculating support, confidence and interest
#
# Calculate these measures and write down how you computed things, not just the answers.
#
#
# #### 5.3.1
#  Suppose we have market basket data consisting of 100 transactions and 20 items. The support for item $ \text{a} = 45 \%$, the support for item $ \text{b} = 80 \%$ and the support for itemset $ \text{ {a,b }} = 30 \%$. Let the support and confidence thresholds be 20$ \%$ and 60$ \%$, respectively.
#
# 1. (0.5 points) Compute the confidence of the association rule $ \text{ {a } } \rightarrow   \text{{b }} $. Is the rule interesting according to the confidence measure?
#
# 2. (0.5 points) Compute the interest measure (or lift, see slide 44 of chapter 6 or https://en.wikipedia.org/wiki/Lift_(data_mining)) for the association pattern $ \text{ {a } } \rightarrow   \text{{b }} $. Describe the nature of the relationship between item $ \text{a}$ and item $ \text{b}$  in terms of the itemset measure.
# 3. (1 points) What conclusion can you draw from the results of parts (1) and (2)?
#
# 4. (1.5 points) Prove that if the confidence of the rule $ \text{ {a } } \rightarrow   \text{{b }} $ is less than the support of $ \text{ {b }}$  then
# $$
# c(  \text{ {~a } } \rightarrow   \text{{b }})> c(  \text{ {a } } \rightarrow   \text{{b }})
# $$
# and
# $$
# c(  \text{ {~a } } \rightarrow   \text{{b }})> s( {b })
# $$
#
# where $ \text{c(.)}$  denotes the rule confidence and  $ \text{s(.)}$ denote the support of an itemset.
#
# Hint: To prove the statement rewrite the confidence and the support of the rule in terms of probabilities:
# $$
# c(  \text{ {a } } \rightarrow   \text{{b }})=  \frac{P( {a,b })}{P( {a })}
# $$
#
# and
#
# $$
# s( {b })=P( {b })
# $$
#
# Further more, make use of probability rules such as $p(b) = p(\text{~}a,b) + p(a,b)$ and $p(\text{~}a) = 1 - p(a)$ and algebraic rules such as $$ \frac{p(a,b)}{p(b)} < p(a) \rightarrow 1 - \frac{p(a,b)}{p(b)} > 1 - p(a) $$

# %% [markdown]
# *Double click to type your answer for 5.3.1 here:*
# Please click on this field, otherwise it seems a bit rubbish.
# 1.
# confidence = P(a,b)/P(a) = 0.3/0.45 = 2/3
# p = 0.8
# p > confidence. So the rule is uninteresting.
#
# 2.
# interest measure = P(b|a)/P(b) = (2/3) / 0.8 = 0.83333333333
# interest measure < 1. Therefore it is negatively associated.
#
# 3.High confidence rules may not (always) be interesting, it was not in this instance. In this case the Lift was negatively ascociated.
# 4.
# 1) Suppose:
# c({a} -> {b}) = (P(a,b)/ P(a)) < P(b), which implies P(a)*P(b) > P(a,b).
#
# c({~a} -> {b}) = P(~a,b)/ P(~a) = (P(b) − P(a,b)) / (1 − P(a))
#
# Thus, we can write:
# c({~a} -> {b}) − c({a}) -> {b}) = (P(b) − P(a,b)) / (1 − P(a)) - (P(a,b)/ P(a)) = (P(a)*P(b) − P(a,b))/(P(a)*(1 − P(a))
#
# which is positive because,  P({a})P({b}) > P({a,b}
#
# 2)
# c({~a} −> {b}) − s(b) = (P(b) − P(a,b)) / (1 − P(a)) - P(b) = (P(a)*P(b) − P(a,b)) / (1 − P(a))
#
# This is positive because P(a)*P(b) > P(a,b)

# %% [markdown]
# #### 5.3.2
#
# (3 points) Consider the relationships between customers who buy high-definition televisions and exercise machines as shown in Table 2 and 3.
#
# 1. Compute the odd ratios for both tables.
# 2. Compute the $\phi$-coefficient for both tables.
# 3. Compute the interest factor for both tables.
#
# For Table 3 you should compute measures given above separately for College
# Students and for Adults. For each of the measures, describe how the direction
# of association changes when data is pooled together (Table 2) instead of being
# separated into two groups (Table 3)
#
# ##### Table 2: Two way contingency table between the sale of high-definition television and exercise machine
# | |   Buy Exercise machine |     |     |
# | :------------- | -------------:| :-----------:| :----------:|
# | **Buy HDTV     ** | yes | no | total |
# | yes  | 105| 87 | 192 |
# | no | 40| 62 | 102 |
# | total | 145 | 149 | 294 |
#
#
# ##### Table 3: Example of three-way contingency table
# | | |   Buy Exercise machine |     |     |
# |--- | :------------- | -------------:| :-----------:| :----------:|
# |**Customer group** | **Buy HDTV     ** | yes | no | total |
# |College students | yes  | 2| 9 | 11 |
# | | no | 5| 20 | 25 |
# | Working adults | yes  | 103| 78 | 181 |
# | | no | 35| 42 | 77 |

# %% [markdown]
# *Double click to type your answer for 5.3.2 here:
# Please click on this field, otherwise it seems a bit rubbish.
#
# Total:
# odd ratio = (105/87)/(40/62) = ~ 1.87069
# ϕ = ((105/294) - (192/294) (145/294))/(root ((192/294) (102/294) (145/294) (149/294))) = ~ 0.14730
# interest = (105/294) / 145 = ~ 0.00246
#
# Students:
# odd ratio = (2/9)/(5/20) = 8/9 (~0.88889)
# ϕ = ((2/36) - (11/36) (7/36))/(root ((11/36) (25/36) (7/36) (29/36))) = ~ -0.02116
# interest = (2/36) / 7 = ~ 0.00794
#
# Adults:
# odd ratio = (103/78)/(35/42) = ~ 1.58462
# ϕ = ((103/258) - (181/258) (138/258))/(root ((181/258) (77/258) (138/258) (120/258))) = ~ 0.10506
# interest = (103/258) / 138 = ~ 0.00289
#
# When data is pooled together the odd ratio and the ϕ are both higher than the seperate data. The interest is lower when the data is pooled together.
